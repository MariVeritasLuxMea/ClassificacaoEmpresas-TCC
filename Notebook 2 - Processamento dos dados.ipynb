# %% [markdown]
# # Processamento dos dados

# %%
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.7.9

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd
import numpy as np
import sqlite3
import re
from IPython.display import display
from zipfile import ZipFile  

pd.options.display.max_columns = None

# %% [markdown]
# ## Dados das Ocorrências
# Partindo dos dados de todas as ocorrências registradas no Compras Governamentais, vamos obter o número de ocorrências por fornecedor, excluindo as ocorrências que não tem relação com execução contratual.

# %%
ocorrencias = pd.read_csv('./ocorrencias.csv', encoding = 'latin-1')

# %%
ocorrencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260012 entries, 0 to 260011
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Id                    260012 non-null  int64
#  1   CNPJ                  248333 non-null  object
#  2   CPF                   551 non-null     object
#  3   Tipo pessoa           248884 non-null  object
#  4   Número do Processo    260011 non-null  object
#  5   Unidade Cadastradora  260012 non-null  object
#  6   Tipo de Ocorrência    260012 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 13.9+ MB

# %% [markdown]
# Não vamos utilizar os dados dos fornecedores Pessoa Física, já que os CPFs estão mascarados e nosso interesse, na presente análise, está nas Pessoas Jurídicas, que são a imensa maioria dos fornecedores do Governo Federal.

# %%
ocorrencias.dropna(subset = ['CPF']).dropna(axis = 1, how = 'all').head() #Exibindo alguns exemplos de CPFs mascarados
# Out:
#           Id                                                CPF Tipo pessoa  \
# 375      376     Fornecedor ***725278**:  RONALD REMONDY JUNIOR          PF
# 4224    4226   Fornecedor ***429031**:  THIAGO SILVEIRA CORREIA          PF
# 8183    8190  Fornecedor ***822201**:  ROBERT FAGNER INACIO ...          PF
# 8331    8338  Fornecedor ***219500**:  ALEXANDRE RAFAEL LOTT...          PF
# 16886  16911           Fornecedor ***821916**:  JOAO PAULO DIAS          PF
#
#       Número do Processo                               Unidade Cadastradora  \
# 375    03111003027200770                     200999: MINISTÉRIO DA ECONOMIA
# 4224     230000590132007     153234: ESCOLA AGROTECNICA FEDERAL DE CERES/GO
# 8183          00001/2008  160101: 23 COMPANHIA DE ENGENHARIA DE COMBATE-...
# 8331       DISP 126/2010     160435: 7 REGIMENTO DE CAVALARIA MECANIZADO/RS
# 16886        2003MAUA007                     160106: 2 BATALHAO FERROVIáRIO
#
#                                      Tipo de Ocorrência
# 375                       7: Outros Tipos de Ocorrência
# 4224                      7: Outros Tipos de Ocorrência
# 8183   1: Advertência - Lei nº 8666/93, art. 87, inc. I
# 8331               6: Inativação a Pedido do Fornecedor
# 16886                     7: Outros Tipos de Ocorrência

# %%
ocorrencias['Tipo de Ocorrência'].unique()
# Out:
# array(['7: Outros Tipos de Ocorrência', '8: Legado',
#        '1: Advertência - Lei nº 8666/93, art. 87, inc. I',
#        '2: Multa - Lei nº 8666/93, art. 87, inc. II',
#        '6: Inativação a Pedido do Fornecedor',
#        '5: Impedimento de Licitar e Contratar - Lei nº 10.520/02, art. 7º',
#        '3: Suspensão Temporária - Lei nº 8666/93, art. 87, inc. III',
#        '4: Declaração de Inidoneidade - Lei nº 8666/93, art. 87, inc. IV',
#        '9: Reativação a Pedido do Fornecedor', '10: Dinâmica'],
#       dtype=object)

# %% [markdown]
# Os tipos de ocorrência _Inativação a Pedido do Fornecedor_ e _Reativação a Pedido do Fornecedor_ não tem relação com problemas na execução contratual, então vamos excluir as linhas que se referem a esses tipos de ocorrências, deixando apenas as de interesse.

# %%
ocorrenciasInteresse = ['1: Advertência - Lei nº 8666/93, art. 87, inc. I',
                        '2: Multa - Lei nº 8666/93, art. 87, inc. II',
                        '3: Suspensão Temporária - Lei nº 8666/93, art. 87, inc. III',
                        '4: Declaração de Inidoneidade - Lei nº 8666/93, art. 87, inc. IV',
                        '5: Impedimento de Licitar e Contratar - Lei nº 10.520/02, art. 7º',
                        '7: Outros Tipos de Ocorrência', 
                        '8: Legado',
                        '10: Dinâmica']

ocorrencias = ocorrencias[ocorrencias['Tipo de Ocorrência'].isin(ocorrenciasInteresse)]
ocorrencias.head()
# Out:
#    Id CNPJ  CPF Tipo pessoa Número do Processo  \
# 0   1  NaN  NaN         NaN  00001005825200281
# 1   2  NaN  NaN         NaN  03110018451201024
# 2   3  NaN  NaN         NaN  03110006265201042
# 3   4  NaN  NaN         NaN  04500004532200982
# 4   5  NaN  NaN         NaN  03000004162200951
#
#              Unidade Cadastradora             Tipo de Ocorrência
# 0  200999: MINISTÉRIO DA ECONOMIA  7: Outros Tipos de Ocorrência
# 1  200999: MINISTÉRIO DA ECONOMIA  7: Outros Tipos de Ocorrência
# 2  200999: MINISTÉRIO DA ECONOMIA  7: Outros Tipos de Ocorrência
# 3  200999: MINISTÉRIO DA ECONOMIA                      8: Legado
# 4  200999: MINISTÉRIO DA ECONOMIA                      8: Legado

# %%
ocorrencias['Tipo de Ocorrência'].unique()
# Out:
# array(['7: Outros Tipos de Ocorrência', '8: Legado',
#        '1: Advertência - Lei nº 8666/93, art. 87, inc. I',
#        '2: Multa - Lei nº 8666/93, art. 87, inc. II',
#        '5: Impedimento de Licitar e Contratar - Lei nº 10.520/02, art. 7º',
#        '3: Suspensão Temporária - Lei nº 8666/93, art. 87, inc. III',
#        '4: Declaração de Inidoneidade - Lei nº 8666/93, art. 87, inc. IV',
#        '10: Dinâmica'], dtype=object)

# %% [markdown]
# Excluindo as linhas que não se referem a pessoas jurídicas:

# %%
ocorrencias = ocorrencias.dropna(subset = ['CNPJ']).dropna(axis = 1, how = 'all')

# %%
ocorrencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247840 entries, 124 to 260011
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Id                    247840 non-null  int64
#  1   CNPJ                  247840 non-null  object
#  2   Tipo pessoa           247840 non-null  object
#  3   Número do Processo    247840 non-null  object
#  4   Unidade Cadastradora  247840 non-null  object
#  5   Tipo de Ocorrência    247840 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.2+ MB

# %%
ocorrencias.head()
# Out:
#       Id                                               CNPJ Tipo pessoa  \
# 124  125  Fornecedor 00.725.347/0001-00:  CONSTRUTORA GA...          PJ
# 238  239  Fornecedor 03.707.204/0001-55:  C.R.O. CONSTRU...          PJ
# 675  676  Fornecedor 32.952.822/0001-69:  TERTEC CONSTRU...          PJ
# 929  930  Fornecedor 88.674.080/0001-01:  TRAMONTINA ELE...          PJ
# 957  958  Fornecedor 00.000.000/0001-91:  BANCO DO BRASI...          PJ
#
#     Número do Processo                               Unidade Cadastradora  \
# 124  04300006506200783                     200999: MINISTÉRIO DA ECONOMIA
# 238  03111001829200826                     200999: MINISTÉRIO DA ECONOMIA
# 675  04300004855200761                     200999: MINISTÉRIO DA ECONOMIA
# 929  04300004293200411                     200999: MINISTÉRIO DA ECONOMIA
# 957    63015375/201019  791180: BASE AEREA NAVAL DE SAO PEDRO DA ALDEI...
#
#                                    Tipo de Ocorrência
# 124                     7: Outros Tipos de Ocorrência
# 238                     7: Outros Tipos de Ocorrência
# 675                     7: Outros Tipos de Ocorrência
# 929                     7: Outros Tipos de Ocorrência
# 957  1: Advertência - Lei nº 8666/93, art. 87, inc. I

# %% [markdown]
# Na coluna CNPJ, queremos deixar apenas o número do CNPJ, sem a palavra Fornecedor e o sem o nome da empresa.

# %%
ocorrencias['CNPJ'] = ocorrencias['CNPJ'].str.split(":", n = 1, expand = True)[0]
ocorrencias['CNPJ'] = ocorrencias['CNPJ'].apply(lambda x: re.sub('[^0-9]', '', x))

# %%
ocorrencias.head()
# Out:
#       Id            CNPJ Tipo pessoa Número do Processo  \
# 124  125  00725347000100          PJ  04300006506200783
# 238  239  03707204000155          PJ  03111001829200826
# 675  676  32952822000169          PJ  04300004855200761
# 929  930  88674080000101          PJ  04300004293200411
# 957  958  00000000000191          PJ    63015375/201019
#
#                                   Unidade Cadastradora  \
# 124                     200999: MINISTÉRIO DA ECONOMIA
# 238                     200999: MINISTÉRIO DA ECONOMIA
# 675                     200999: MINISTÉRIO DA ECONOMIA
# 929                     200999: MINISTÉRIO DA ECONOMIA
# 957  791180: BASE AEREA NAVAL DE SAO PEDRO DA ALDEI...
#
#                                    Tipo de Ocorrência
# 124                     7: Outros Tipos de Ocorrência
# 238                     7: Outros Tipos de Ocorrência
# 675                     7: Outros Tipos de Ocorrência
# 929                     7: Outros Tipos de Ocorrência
# 957  1: Advertência - Lei nº 8666/93, art. 87, inc. I

# %% [markdown]
# A seguir, contamos quantas ocorrencias existem para cada CNPJ.

# %%
quantidadePorCnpj = {}
for cnpj in ocorrencias['CNPJ'].unique():
    numeroOcorrencias = len(ocorrencias[ocorrencias['CNPJ'] == cnpj])
    if cnpj not in quantidadePorCnpj:
        quantidadePorCnpj[cnpj] = numeroOcorrencias
    else:
        quantidadePorCnpj[cnpj] = quantidadePorCnpj[cnpj] + numeroOcorrencias

# %%
ocorrenciasPorFornecedor = pd.DataFrame.from_dict(quantidadePorCnpj, dtype = 'int64', orient = 'index', columns = ['ocorrencias'])

# %%
ocorrenciasPorFornecedor.reset_index(inplace = True)

# %%
ocorrenciasPorFornecedor.rename(columns = {'index': 'CNPJ'}, inplace = True)

# %%
ocorrenciasPorFornecedor.head()
# Out:
#              CNPJ  ocorrencias
# 0  00725347000100            6
# 1  03707204000155            2
# 2  32952822000169            1
# 3  88674080000101            1
# 4  00000000000191            8

# %% [markdown]
# Verificando se todos os CNPJs são únicos (número de linhas deve ser igual à quantidade de valores únicos):

# %%
ocorrenciasPorFornecedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39730 entries, 0 to 39729
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CNPJ         39730 non-null  object
#  1   ocorrencias  39730 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 620.9+ KB

# %%
ocorrenciasPorFornecedor['CNPJ'].nunique()
# Out:
# 39730

# %%
ocorrenciasPorFornecedor.to_csv('./ocorrenciasPorFornecedor.csv', index = False)

# %% [markdown]
# ## Dados dos Contratos
# A partir dos dados dos contratos, vamos obter os CNPJs dos contratados pelo Governo Federal. Consideraremos apenas as contratações realizadas por UGs que registraram pelo menos uma ocorrência no sistema.

# %%
ugs = ocorrencias['Unidade Cadastradora'].str.split(pat = ':', expand = True)

# %%
ugs.isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
ugs.tail()
# Out:
#              0                                               1
# 260007  925936   ECT - DIRETORIA REGIONAL SAO PAULO METROPOLIT
# 260008  925936   ECT - DIRETORIA REGIONAL SAO PAULO METROPOLIT
# 260009  148002                                   CORREIOS SEDE
# 260010  148002                                   CORREIOS SEDE
# 260011  253002   AGENCIA NACIONAL DE VIGILANCIA SANITARIA - DF

# %% [markdown]
# Conforme o [dicionário de dados dos contratos](http://www.portaltransparencia.gov.br/pagina-interna/603396-dicionario-de-dados-contratos-firmados), vemos que cada arquivo _.zip_ contém quatro arquivos para o mês. A partir das tabelas _Compras_ podemos obter quantos contratos o governo firmou com cada fornecedor.

# %%
pasta = './contratos/'
for arquivoZip in os.listdir(pasta):
    arquivoParaExtrair = arquivoZip.replace('.zip', '_Compras.csv')
    ZipFile(pasta + arquivoZip).extractall(pasta + 'contratados/')

# Excluindo os arquivos que não serão usados
pasta = './contratos/contratados/'
for arquivo in os.listdir(pasta):
    if 'Compras' not in arquivo:
        os.remove(pasta + arquivo)

# %% [markdown]
# Abaixo, vamos abrir cada arquivo da pasta e contar os contratos de cada fornecedor que aparece no arquivo, e em seguida, incluir as informações num dicionário. Ao final do processamento de todos os arquivos, criaremos um DataFrame a partir do dicionário.

# %%
contratosFornecedor = {}

# %%
pasta = './contratos/contratados/'
for arquivo in os.listdir(pasta):
    print(arquivo)
    for contratos in pd.read_csv(pasta + arquivo, sep = ';', dtype = 'str', encoding = 'latin-1', chunksize = 1000):
        contratos.drop(contratos.loc[~contratos['Código UG'].isin(ugs[0])].index, inplace = True)
        for cnpjFornecedor in contratos['CNPJ Contratado'].unique():
            quantidadeContratos = len(contratos[contratos['CNPJ Contratado'] == cnpjFornecedor])
            if cnpjFornecedor not in contratosFornecedor:
                contratosFornecedor[cnpjFornecedor] = quantidadeContratos
            else:
                quantidadeContratosAnterior = contratosFornecedor[cnpjFornecedor]
                contratosFornecedor[cnpjFornecedor] = quantidadeContratosAnterior + quantidadeContratos
# Out:
# 201301_Compras.csv
# 201302_Compras.csv
# 201303_Compras.csv
# 201304_Compras.csv
# 201305_Compras.csv
# 201306_Compras.csv
# 201307_Compras.csv
# 201308_Compras.csv
# 201309_Compras.csv
# 201310_Compras.csv
# 201311_Compras.csv
# 201312_Compras.csv
# 201401_Compras.csv
# 201402_Compras.csv
# 201403_Compras.csv
# 201404_Compras.csv
# 201405_Compras.csv
# 201406_Compras.csv
# 201407_Compras.csv
# 201408_Compras.csv
# 201409_Compras.csv
# 201410_Compras.csv
# 201411_Compras.csv
# 201412_Compras.csv
# 201501_Compras.csv
# 201502_Compras.csv
# 201503_Compras.csv
# 201504_Compras.csv
# 201505_Compras.csv
# 201506_Compras.csv
# 201507_Compras.csv
# 201508_Compras.csv
# 201509_Compras.csv
# 201510_Compras.csv
# 201511_Compras.csv
# 201512_Compras.csv
# 201601_Compras.csv
# 201602_Compras.csv
# 201603_Compras.csv
# 201604_Compras.csv
# 201605_Compras.csv
# 201606_Compras.csv
# 201607_Compras.csv
# 201608_Compras.csv
# 201609_Compras.csv
# 201610_Compras.csv
# 201611_Compras.csv
# 201612_Compras.csv
# 201701_Compras.csv
# 201702_Compras.csv
# 201703_Compras.csv
# 201704_Compras.csv
# 201705_Compras.csv
# 201706_Compras.csv
# 201707_Compras.csv
# 201708_Compras.csv
# 201709_Compras.csv
# 201710_Compras.csv
# 201711_Compras.csv
# 201712_Compras.csv
# 201801_Compras.csv
# 201802_Compras.csv
# 201803_Compras.csv
# 201804_Compras.csv
# 201805_Compras.csv
# 201806_Compras.csv
# 201807_Compras.csv
# 201808_Compras.csv
# 201809_Compras.csv
# 201810_Compras.csv
# 201811_Compras.csv
# 201812_Compras.csv
# 201901_Compras.csv
# 201902_Compras.csv
# 201903_Compras.csv
# 201904_Compras.csv
# 201905_Compras.csv
# 201906_Compras.csv
# 201907_Compras.csv
# 201908_Compras.csv
# 201909_Compras.csv
# 201910_Compras.csv
# 201911_Compras.csv
# 201912_Compras.csv
# 202001_Compras.csv
# 202002_Compras.csv
# 202003_Compras.csv
# 202004_Compras.csv
# 202005_Compras.csv
# 202006_Compras.csv
# 202007_Compras.csv
# 202008_Compras.csv
# 202009_Compras.csv
# 202010_Compras.csv
# 202011_Compras.csv
# 202012_Compras.csv
# 202101_Compras.csv
# 202102_Compras.csv
# 202103_Compras.csv

# %%
contratosPorFornecedor = pd.DataFrame.from_dict(contratosFornecedor, orient = 'index', columns = ['contratos'])

# %%
contratosPorFornecedor.reset_index(inplace = True)

# %%
contratosPorFornecedor.rename(columns = {'index': 'CNPJ'}, inplace = True)

# %%
contratosPorFornecedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63135 entries, 0 to 63134
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CNPJ       63135 non-null  object
#  1   contratos  63135 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 986.6+ KB

# %%
contratosPorFornecedor['CNPJ'].nunique()
# Out:
# 63135

# %%
contratosPorFornecedor.head()
# Out:
#              CNPJ  contratos
# 0  04358183000172          4
# 1  05120923000109         60
# 2  07918078000139          1
# 3  00212655000123        270
# 4  05156333000128         15

# %% [markdown]
# Nos dados de contratos baixados do Portal da Transparência constam informações de todos os contratados, inclusive os que são Pessoas Físicas e empresas estrangeiras que não possuem CNPJ. Vamos verificar quantas das linhas da coluna cnpj não contém CNPJs:

# %% [markdown]
# Removendo as letras:

# %%
contratosPorFornecedor['CNPJ'] = contratosPorFornecedor['CNPJ'].apply(lambda x: re.sub('[^0-9]', '', x))

# %% [markdown]
# Contando quantas linhas contém CNPJs e quantas não:

# %%
print('CNPJs: ' + str(contratosPorFornecedor['CNPJ'].loc[contratosPorFornecedor['CNPJ'].str.len() == 14].count()))
print('Outros: ' + str(contratosPorFornecedor['CNPJ'].loc[contratosPorFornecedor['CNPJ'].str.len() != 14].count()))
print('Total de linhas: '  + str(len(contratosPorFornecedor)))
# Out:
# CNPJs: 56855
# Outros: 6280
# Total de linhas: 63135

# %% [markdown]
# Vemos que existem 6.280 contratados que não são pessoas jurídicas. Vamos excluir estas linhas e trabalhar apenas com os fornecedores PJ, que são o nosso foco nesta análise.

# %%
contratosPorFornecedor.drop(contratosPorFornecedor['CNPJ'].loc[contratosPorFornecedor['CNPJ'].str.len() != 14].index, inplace = True)

# %%
contratosPorFornecedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56855 entries, 0 to 63134
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CNPJ       56855 non-null  object
#  1   contratos  56855 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.3+ MB

# %%
contratosPorFornecedor.to_csv('./contratosPorFornecedor.csv', index = False)

# %% [markdown]
# ## Dados das Licitações
# A partir dos dados das licitações, vamos obter os CNPJs dos fornecedores do Governo Federal e o respectivo número de participações e vitórias. Consideraremos apenas participações e vitórias em licitações realizadas por UGs que registraram pelo menos uma ocorrência no sistema e os CNPJs de empresas que firmaram pelo menos um contrato com o Governo Federal.

# %%
cnpjs = contratosPorFornecedor['CNPJ']

# %%
cnpjs
# Out:
# 0        04358183000172
# 1        05120923000109
# 2        07918078000139
# 3        00212655000123
# 4        05156333000128
#               ...
# 63130    16611560000112
# 63131    37045935000102
# 63132    84084383000113
# 63133    18376070000104
# 63134    35613306000106
# Name: CNPJ, Length: 56855, dtype: object

# %% [markdown]
# Conforme o [dicionário de dados das licitações](http://www.portaltransparencia.gov.br/pagina-interna/603389-dicionario-de-dados-licitacoes), vemos que cada arquivo _.zip_ contém três arquivos para o mês (_ItensLicitação_, _Licitação_ e _ParticipantesLicitação_). Na tabela _ParticipantesLicitação_ temos, para cada item de cada licitação, os fornecedores que concorreram e qual ganhou (através de _Flag vencedor_). Portanto, a partir dessas tabelas _ParticipantesLicitacao_ podemos obter, para cada fornecedor, a quantidade de itens que ele concorreu e a quantidade de itens que venceu.

# %%
pasta = './licitacoes/'
for arquivoZip in os.listdir(pasta):
    arquivoParaExtrair = arquivoZip.replace('.zip', '_ParticipantesLicitação.csv')
    ZipFile(pasta + arquivoZip).extractall(pasta + 'participantes/')

# Excluindo os arquivos que não serão usados
pasta = './licitacoes/participantes/'
for arquivo in os.listdir(pasta):
    if 'Participantes' not in arquivo:
        os.remove(pasta + arquivo)

# %% [markdown]
# Abaixo, vamos abrir cada arquivo da pasta e contar as participações e vitórias de cada fornecedor que aparece no arquivo, e em seguida, incluir as informações num dicionário. Ao final do processamento de todos os arquivos, criaremos um DataFrame a partir do dicionário. Como alguns arquivos possuem muitas linhas (em alguns casos quase 1,5 milhão de linhas), a obtenção dos CNPJs únicos e do número de vitórias para cada CNPJ pode demorar muito, então vamos ler cada arquivo e fazer a contagem por partes.

# %%
itensPorFornecedor = {}

# %%
pasta = './licitacoes/participantes/'
for arquivo in os.listdir(pasta):
    print(arquivo)
    for itens in pd.read_csv(pasta + arquivo, sep = ';', dtype = 'str', encoding = 'latin-1', chunksize = 1000):
        itens.drop(itens.loc[~itens['Código UG'].isin(ugs[0])].index, inplace = True)
        itens.drop(itens.loc[~itens['CNPJ Participante'].isin(cnpjs)].index, inplace = True)
        for cnpjFornecedor in itens['CNPJ Participante'].unique():
            itensParticipacao = itens[itens['CNPJ Participante'] == cnpjFornecedor]
            quantidadeParticipacoes = len(itensParticipacao)
            quantidadeVitorias = len(itensParticipacao[itensParticipacao['Flag Vencedor'] == 'SIM'])
            if cnpjFornecedor not in itensPorFornecedor:
                itensPorFornecedor[cnpjFornecedor] = [quantidadeParticipacoes, quantidadeVitorias]
            else:
                quantPartAnterior = itensPorFornecedor[cnpjFornecedor][0]
                quantVitAnterior = itensPorFornecedor[cnpjFornecedor][1]
                itensPorFornecedor[cnpjFornecedor] = [quantPartAnterior + quantidadeParticipacoes, quantVitAnterior + quantidadeVitorias]
# Out:
# 201301_ParticipantesLicitaç╞o.csv
# 201302_ParticipantesLicitaç╞o.csv
# 201303_ParticipantesLicitaç╞o.csv
# 201304_ParticipantesLicitaç╞o.csv
# 201305_ParticipantesLicitaç╞o.csv
# 201306_ParticipantesLicitaç╞o.csv
# 201307_ParticipantesLicitaç╞o.csv
# 201308_ParticipantesLicitaç╞o.csv
# 201309_ParticipantesLicitaç╞o.csv
# 201310_ParticipantesLicitaç╞o.csv
# 201311_ParticipantesLicitaç╞o.csv
# 201312_ParticipantesLicitaç╞o.csv
# 201401_ParticipantesLicitaç╞o.csv
# 201402_ParticipantesLicitaç╞o.csv
# 201403_ParticipantesLicitaç╞o.csv
# 201404_ParticipantesLicitaç╞o.csv
# 201405_ParticipantesLicitaç╞o.csv
# 201406_ParticipantesLicitaç╞o.csv
# 201407_ParticipantesLicitaç╞o.csv
# 201408_ParticipantesLicitaç╞o.csv
# 201409_ParticipantesLicitaç╞o.csv
# 201410_ParticipantesLicitaç╞o.csv
# 201411_ParticipantesLicitaç╞o.csv
# 201412_ParticipantesLicitaç╞o.csv
# 201501_ParticipantesLicitaç╞o.csv
# 201502_ParticipantesLicitaç╞o.csv
# 201503_ParticipantesLicitaç╞o.csv
# 201504_ParticipantesLicitaç╞o.csv
# 201505_ParticipantesLicitaç╞o.csv
# 201506_ParticipantesLicitaç╞o.csv
# 201507_ParticipantesLicitaç╞o.csv
# 201508_ParticipantesLicitaç╞o.csv
# 201509_ParticipantesLicitaç╞o.csv
# 201510_ParticipantesLicitaç╞o.csv
# 201511_ParticipantesLicitaç╞o.csv
# 201512_ParticipantesLicitaç╞o.csv
# 201601_ParticipantesLicitaç╞o.csv
# 201602_ParticipantesLicitaç╞o.csv
# 201603_ParticipantesLicitaç╞o.csv
# 201604_ParticipantesLicitaç╞o.csv
# 201605_ParticipantesLicitaç╞o.csv
# 201606_ParticipantesLicitaç╞o.csv
# 201607_ParticipantesLicitaç╞o.csv
# 201608_ParticipantesLicitaç╞o.csv
# 201609_ParticipantesLicitaç╞o.csv
# 201610_ParticipantesLicitaç╞o.csv
# 201611_ParticipantesLicitaç╞o.csv
# 201612_ParticipantesLicitaç╞o.csv
# 201701_ParticipantesLicitaç╞o.csv
# 201702_ParticipantesLicitaç╞o.csv
# 201703_ParticipantesLicitaç╞o.csv
# 201704_ParticipantesLicitaç╞o.csv
# 201705_ParticipantesLicitaç╞o.csv
# 201706_ParticipantesLicitaç╞o.csv
# 201707_ParticipantesLicitaç╞o.csv
# 201708_ParticipantesLicitaç╞o.csv
# 201709_ParticipantesLicitaç╞o.csv
# 201710_ParticipantesLicitaç╞o.csv
# 201711_ParticipantesLicitaç╞o.csv
# 201712_ParticipantesLicitaç╞o.csv
# 201801_ParticipantesLicitaç╞o.csv
# 201802_ParticipantesLicitaç╞o.csv
# 201803_ParticipantesLicitaç╞o.csv
# 201804_ParticipantesLicitaç╞o.csv
# 201805_ParticipantesLicitaç╞o.csv
# 201806_ParticipantesLicitaç╞o.csv
# 201807_ParticipantesLicitaç╞o.csv
# 201808_ParticipantesLicitaç╞o.csv
# 201809_ParticipantesLicitaç╞o.csv
# 201810_ParticipantesLicitaç╞o.csv
# 201811_ParticipantesLicitaç╞o.csv
# 201812_ParticipantesLicitaç╞o.csv
# 201901_ParticipantesLicitaç╞o.csv
# 201902_ParticipantesLicitaç╞o.csv
# 201903_ParticipantesLicitaç╞o.csv
# 201904_ParticipantesLicitaç╞o.csv
# 201905_ParticipantesLicitaç╞o.csv
# 201906_ParticipantesLicitaç╞o.csv
# 201907_ParticipantesLicitaç╞o.csv
# 201908_ParticipantesLicitaç╞o.csv
# 201909_ParticipantesLicitaç╞o.csv
# 201910_ParticipantesLicitaç╞o.csv
# 201911_ParticipantesLicitaç╞o.csv
# 201912_ParticipantesLicitaç╞o.csv
# 202001_ParticipantesLicitaç╞o.csv
# 202002_ParticipantesLicitaç╞o.csv
# 202003_ParticipantesLicitaç╞o.csv
# 202004_ParticipantesLicitaç╞o.csv
# 202005_ParticipantesLicitaç╞o.csv
# 202006_ParticipantesLicitaç╞o.csv
# 202007_ParticipantesLicitaç╞o.csv
# 202008_ParticipantesLicitaç╞o.csv
# 202009_ParticipantesLicitaç╞o.csv
# 202010_ParticipantesLicitaç╞o.csv
# 202011_ParticipantesLicitaç╞o.csv
# 202012_ParticipantesLicitaç╞o.csv
# 202101_ParticipantesLicitaç╞o.csv
# 202102_ParticipantesLicitaç╞o.csv

# %%
licitacoesPorFornecedor = pd.DataFrame.from_dict(itensPorFornecedor, orient = 'index', columns = ['participacoes', 'vitorias'])

# %%
licitacoesPorFornecedor.reset_index(inplace = True)

# %%
licitacoesPorFornecedor.rename(columns = {'index': 'CNPJ'}, inplace = True)

# %%
licitacoesPorFornecedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52749 entries, 0 to 52748
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CNPJ           52749 non-null  object
#  1   participacoes  52749 non-null  int64
#  2   vitorias       52749 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ MB

# %%
licitacoesPorFornecedor['CNPJ'].nunique()
# Out:
# 52749

# %% [markdown]
# Conferindo se todas as linhas contém CNPJs:

# %%
print('CNPJs: ' + str(licitacoesPorFornecedor['CNPJ'].loc[licitacoesPorFornecedor['CNPJ'].str.len() == 14].count()))
print('Outros: ' + str(licitacoesPorFornecedor['CNPJ'].loc[licitacoesPorFornecedor['CNPJ'].str.len() != 14].count()))
print('Total de linhas: '  + str(len(licitacoesPorFornecedor)))
# Out:
# CNPJs: 52749
# Outros: 0
# Total de linhas: 52749

# %%
licitacoesPorFornecedor.to_csv('./licitacoesPorFornecedor.csv', index = False)

# %% [markdown]
# ## Dados da base do CNPJ

# %%
baseCnpj = sqlite3.connect('./qsacnpj/bd_dados_qsa_cnpj.db')
cursor = baseCnpj.cursor()

# %% [markdown]
# Verificando quais as tabelas que existem no banco:

# %%
tabelas = cursor.execute('SELECT name FROM sqlite_master WHERE type="table"').fetchall()
tabelas
# Out:
# [('cnpj_dados_cadastrais_pj',),
#  ('cnpj_dados_socios_pj',),
#  ('cnpj_dados_cnae_secundario_pj',),
#  ('tab_cnpj_entes_publicos',),
#  ('tab_qualificacao_responsavel_socio',),
#  ('tab_situacao_cadastral',),
#  ('tab_natureza_juridica',),
#  ('tab_cnae',),
#  ('tab_codigo_municipios_siafi',)]

# %% [markdown]
# Vamos buscar alguns registros da tabela dos dados cadastrais de CNPJ para verificar que informações estão disponíveis.

# %%
df = pd.read_sql('SELECT * FROM cnpj_dados_cadastrais_pj LIMIT 100', baseCnpj)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   tipo_de_registro             100 non-null    object
#  1   indicador                    100 non-null    object
#  2   tipo_atualizacao             100 non-null    object
#  3   cnpj                         100 non-null    object
#  4   identificador_matriz_filial  100 non-null    object
#  5   razao_social                 100 non-null    object
#  6   nome_fantasia                100 non-null    object
#  7   situacao_cadastral           100 non-null    object
#  8   data_situacao_cadastral      100 non-null    object
#  9   motivo_situacao_cadastral    100 non-null    object
#  10  nm_cidade_exterior           100 non-null    object
#  11  cod_pais                     100 non-null    object
#  12  nm_pais                      100 non-null    object
#  13  codigo_natureza_juridica     100 non-null    object
#  14  data_inicio_atividade        100 non-null    object
#  15  cnae_fiscal                  100 non-null    object
#  16  descricao_tipo_logradouro    100 non-null    object
#  17  logradouro                   100 non-null    object
#  18  numero                       100 non-null    object
#  19  complemento                  100 non-null    object
#  20  bairro                       100 non-null    object
#  21  cep                          100 non-null    object
#  22  uf                           100 non-null    object
#  23  codigo_municipio             100 non-null    object
#  24  municipio                    100 non-null    object
#  25  ddd_telefone_1               100 non-null    object
#  26  ddd_telefone_2               100 non-null    object
#  27  ddd_fax                      100 non-null    object
#  28  correio_eletronico           100 non-null    object
#  29  qualificacao_responsavel     100 non-null    object
#  30  capital_social_empresa       100 non-null    float64
#  31  porte_empresa                100 non-null    object
#  32  opcao_pelo_simples           100 non-null    object
#  33  data_opcao_pelo_simples      0 non-null      object
#  34  data_exclusao_simples        0 non-null      object
#  35  opcao_pelo_mei               100 non-null    object
#  36  situacao_especial            100 non-null    object
#  37  data_situacao_especial       0 non-null      object
#  38  filler                       100 non-null    object
#  39  fim_registro                 100 non-null    object
# dtypes: float64(1), object(39)
# memory usage: 31.4+ KB

# %%
df.head()
# Out:
#   tipo_de_registro indicador tipo_atualizacao            cnpj  \
# 0                1         F                   00000000000191
# 1                1         F                   00000000000272
# 2                1         F                   00000000000353
# 3                1         F                   00000000000434
# 4                1         F                   00000000000515
#
#   identificador_matriz_filial        razao_social  \
# 0                           1  BANCO DO BRASIL SA
# 1                           2  BANCO DO BRASIL SA
# 2                           2  BANCO DO BRASIL SA
# 3                           2  BANCO DO BRASIL SA
# 4                           2  BANCO DO BRASIL SA
#
#                   nome_fantasia situacao_cadastral data_situacao_cadastral  \
# 0                 DIRECAO GERAL                 02              2005-11-03
# 1                   MANAUS (AM)                 02              2005-11-03
# 2  PRESIDENTE VARGAS BELEM (PA)                 02              2005-11-03
# 3          SANTOS - SANTOS (SP)                 02              2005-11-03
# 4              CAMPOS EST.UNIF.                 02              2005-11-03
#
#   motivo_situacao_cadastral nm_cidade_exterior cod_pais nm_pais  \
# 0                        00
# 1                        00
# 2                        00
# 3                        00
# 4                        00
#
#   codigo_natureza_juridica data_inicio_atividade cnae_fiscal  \
# 0                     2038            1966-08-01     6422100
# 1                     2038            1976-08-13     6422100
# 2                     2038            1966-08-01     6422100
# 3                     2038            1966-08-01     6422100
# 4                     2038            1966-08-01     6421200
#
#   descricao_tipo_logradouro                               logradouro numero  \
# 0                    QUADRA  SAUN QUADRA 5 LOTE B TORRES I, II E III     SN
# 1                       RUA                        GUILHERME MOREIRA    315
# 2                                             AVEN PRESIDENTE VARGAS    248
# 3                       RUA                           15 DE NOVEMBRO    195
# 4                     PRACA                           DAS 4 JORNADAS     11
#
#                                          complemento     bairro       cep  uf  \
# 0  ANDAR 1 A 16              SALA  101 A 1601    ...  ASA NORTE  70040912  DF
# 1                                                        CENTRO  69005300  AM
# 2                                                      COMERCIO  66010900  PA
# 3                                                        CENTRO  11010908  SP
# 4                                                        CENTRO  28030002  RJ
#
#   codigo_municipio              municipio ddd_telefone_1 ddd_telefone_2  \
# 0             9701               BRASILIA   61  34939002
# 1             0255                 MANAUS   92  36215500
# 2             0427                  BELEM
# 3             7071                 SANTOS
# 4             5819  CAMPOS DOS GOYTACAZES
#
#         ddd_fax correio_eletronico qualificacao_responsavel  \
# 0  61  34931040    SECEX@BB.COM.BR                       10
# 1                AGE0002@BB.COM.BR                       10
# 2                                                        10
# 3                                                        10
# 4                                                        10
#
#    capital_social_empresa porte_empresa opcao_pelo_simples  \
# 0            9.000000e+10            05                  0
# 1            0.000000e+00            05                  0
# 2            0.000000e+00            05                  0
# 3            0.000000e+00            05                  0
# 4            0.000000e+00            05                  0
#
#   data_opcao_pelo_simples data_exclusao_simples opcao_pelo_mei  \
# 0                    None                  None              N
# 1                    None                  None
# 2                    None                  None
# 3                    None                  None
# 4                    None                  None
#
#   situacao_especial data_situacao_especial filler fim_registro
# 0                                     None                   F
# 1                                     None                   F
# 2                                     None                   F
# 3                                     None                   F
# 4                                     None                   F

# %% [markdown]
# Segundo o [Layout de dados da RFB](http://200.152.38.155/CNPJ/LAYOUT_DADOS_ABERTOS_CNPJ.pdf), temos os seguintes significados dos códigos das colunas que não estão detalhados em outras tabelas no banco:
# ###### identificador_matriz_filial
# * 1: Matriz
# * 2: Filial
#
# ###### porte_empresa
# * 00: Não informado
# * 01: Micro Empresa
# * 03: Empresa de Pequeno Porte
# * 05: Demais
#
# ###### opcao_pelo_simples
# * 0 ou em branco - não optante
# * 5 e 7: optante pelo SIMPLES
# * 6 e 8: excluído do SIMPLES
#
# ###### situacao_cadastral
# * 01: Nula
# * 02: Ativa
# * 03: Suspensa
# * 04: Inapta
# * 08: Baixada

# %% [markdown]
# As naturezas jurídicas estão descritas na tabela _tab_natureza_juridica_:

# %%
natJurid = pd.read_sql('SELECT * FROM tab_natureza_juridica', baseCnpj)
natJurid
# Out:
#    cod_natureza_juridica                               nm_natureza_juridica  \
# 0                      1                              Administração Pública
# 1                      1                              Administração Pública
# 2                      1                              Administração Pública
# 3                      1                              Administração Pública
# 4                      1                              Administração Pública
# ..                   ...                                                ...
# 84                     4                                    Pessoas Físicas
# 85                     4                                    Pessoas Físicas
# 86                     5  Organizações Internacionais e Outras Instituiç...
# 87                     5  Organizações Internacionais e Outras Instituiç...
# 88                     5  Organizações Internacionais e Outras Instituiç...
#
#    cod_subclass_natureza_juridica  \
# 0                            1015
# 1                            1023
# 2                            1031
# 3                            1040
# 4                            1058
# ..                            ...
# 84                           4111
# 85                           4120
# 86                           5010
# 87                           5029
# 88                           5037
#
#                         nm_subclass_natureza_juridica
# 0            Órgão Público do Poder Executivo Federal
# 1   Órgão Público do Poder Executivo Estadual ou d...
# 2          Órgão Público do Poder Executivo Municipal
# 3          Órgão Público do Poder Legislativo Federal
# 4   Órgão Público do Poder Legislativo Estadual ou...
# ..                                                ...
# 84                                          Leiloeiro
# 85                     Produtor Rural (Pessoa Física)
# 86                          Organização Internacional
# 87              Representação Diplomática Estrangeira
# 88              Outras Instituições Extraterritoriais
#
# [89 rows x 4 columns]

# %% [markdown]
# A tabela _tab_cnae_ contém a descrição específica do CNAE (_nm_cnae_), mas também as informações sobre _seção_, _divisão_, _grupo_ e _classe_.

# %%
cnaes = pd.read_sql('SELECT * FROM tab_cnae', baseCnpj)
cnaes
# Out:
#      cod_secao                                           nm_secao cod_divisao  \
# 0            A  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...          01
# 1            A  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...          01
# 2            A  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...          01
# 3            A  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...          01
# 4            A  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...          01
# ...        ...                                                ...         ...
# 1326         S                      OUTRAS ATIVIDADES DE SERVIÇOS          96
# 1327         S                      OUTRAS ATIVIDADES DE SERVIÇOS          96
# 1328         S                      OUTRAS ATIVIDADES DE SERVIÇOS          96
# 1329         S                      OUTRAS ATIVIDADES DE SERVIÇOS          96
# 1330         T                                SERVIÇOS DOMÉSTICOS          97
#
#                                         nm_divisao cod_grupo  \
# 0     AGRICULTURA PECUÁRIA E SERVIÇOS RELACIONADOS      01.1
# 1     AGRICULTURA PECUÁRIA E SERVIÇOS RELACIONADOS      01.1
# 2     AGRICULTURA PECUÁRIA E SERVIÇOS RELACIONADOS      01.1
# 3     AGRICULTURA PECUÁRIA E SERVIÇOS RELACIONADOS      01.1
# 4     AGRICULTURA PECUÁRIA E SERVIÇOS RELACIONADOS      01.1
# ...                                            ...       ...
# 1326        OUTRAS ATIVIDADES DE SERVIÇOS PESSOAIS      96.0
# 1327        OUTRAS ATIVIDADES DE SERVIÇOS PESSOAIS      96.0
# 1328        OUTRAS ATIVIDADES DE SERVIÇOS PESSOAIS      96.0
# 1329        OUTRAS ATIVIDADES DE SERVIÇOS PESSOAIS      96.0
# 1330                           SERVIÇOS DOMÉSTICOS      97.0
#
#                                     nm_grupo cod_classe  \
# 0           Produção de lavouras temporárias    01.11-3
# 1           Produção de lavouras temporárias    01.11-3
# 2           Produção de lavouras temporárias    01.11-3
# 3           Produção de lavouras temporárias    01.11-3
# 4           Produção de lavouras temporárias    01.12-1
# ...                                      ...        ...
# 1326  Outras atividades de serviços pessoais    96.09-2
# 1327  Outras atividades de serviços pessoais    96.09-2
# 1328  Outras atividades de serviços pessoais    96.09-2
# 1329  Outras atividades de serviços pessoais    96.09-2
# 1330                     Serviços domésticos    97.00-5
#
#                                               nm_classe cod_cnae  \
# 0                                    Cultivo de cereais  0111301
# 1                                    Cultivo de cereais  0111302
# 2                                    Cultivo de cereais  0111303
# 3                                    Cultivo de cereais  0111399
# 4     Cultivo de algodão herbáceo e de outras fibras...  0112101
# ...                                                 ...      ...
# 1326  Atividades de serviços pessoais não especifica...  9609206
# 1327  Atividades de serviços pessoais não especifica...  9609207
# 1328  Atividades de serviços pessoais não especifica...  9609208
# 1329  Atividades de serviços pessoais não especifica...  9609299
# 1330                                Serviços domésticos  9700500
#
#                                                 nm_cnae
# 0                                      Cultivo de arroz
# 1                                      Cultivo de milho
# 2                                      Cultivo de trigo
# 3     Cultivo de outros cereais não especificados an...
# 4                           Cultivo de algodão herbáceo
# ...                                                 ...
# 1326       Serviços de tatuagem e colocação de piercing
# 1327                   Alojamento de animais domésticos
# 1328      Higiene e embelezamento de animais domésticos
# 1329  Outras atividades de serviços pessoais não esp...
# 1330                                Serviços domésticos
#
# [1331 rows x 10 columns]

# %% [markdown]
# Estamos focando a análise nas empresas que firmaram contratos com o Governo Federal, ou seja, nos CNPJs que constam nos dados de contratos obtidos no Portal da Transparência. Sendo assim, vamos selecionar no banco de dados apenas as informações sobre estes fornecedores.

# %%
cnpjs = str(contratosPorFornecedor['CNPJ'].to_list()).replace('[', '(').replace(']', ') ')

# %%
query = """
        WITH fornecedores AS
        (   
            SELECT *
            FROM cnpj_dados_cadastrais_pj        
            WHERE cnpj_dados_cadastrais_pj.cnpj IN """ + cnpjs + """
        )
        SELECT fornecedores.cnpj, 
               fornecedores.identificador_matriz_filial, 
               fornecedores.razao_social,
               fornecedores.situacao_cadastral,
               fornecedores.data_inicio_atividade,
               fornecedores.uf,
               fornecedores.codigo_municipio,
               fornecedores.municipio, 
               fornecedores.capital_social_empresa,
               fornecedores.porte_empresa,
               fornecedores.opcao_pelo_simples,
               tab_natureza_juridica.*,
               tab_cnae.* 
        FROM fornecedores
        JOIN tab_natureza_juridica, tab_cnae 
        ON fornecedores.codigo_natureza_juridica = tab_natureza_juridica.cod_subclass_natureza_juridica
        AND fornecedores.cnae_fiscal = tab_cnae.cod_cnae
        """

dadosCadastroCnpj = pd.read_sql(query, baseCnpj)

# %%
baseCnpj.close()

# %%
dadosCadastroCnpj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56850 entries, 0 to 56849
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cnpj                            56850 non-null  object
#  1   identificador_matriz_filial     56850 non-null  object
#  2   razao_social                    56850 non-null  object
#  3   situacao_cadastral              56850 non-null  object
#  4   data_inicio_atividade           56850 non-null  object
#  5   uf                              56850 non-null  object
#  6   codigo_municipio                56850 non-null  object
#  7   municipio                       56850 non-null  object
#  8   capital_social_empresa          56850 non-null  float64
#  9   porte_empresa                   56850 non-null  object
#  10  opcao_pelo_simples              56850 non-null  object
#  11  cod_natureza_juridica           56850 non-null  object
#  12  nm_natureza_juridica            56850 non-null  object
#  13  cod_subclass_natureza_juridica  56850 non-null  object
#  14  nm_subclass_natureza_juridica   56850 non-null  object
#  15  cod_secao                       56850 non-null  object
#  16  nm_secao                        56850 non-null  object
#  17  cod_divisao                     56850 non-null  object
#  18  nm_divisao                      56850 non-null  object
#  19  cod_grupo                       56850 non-null  object
#  20  nm_grupo                        56850 non-null  object
#  21  cod_classe                      56850 non-null  object
#  22  nm_classe                       56850 non-null  object
#  23  cod_cnae                        56850 non-null  object
#  24  nm_cnae                         56850 non-null  object
# dtypes: float64(1), object(24)
# memory usage: 10.8+ MB

# %% [markdown]
# Foram recuperadas 56.850 linhas do banco de dados, porém no DataFrame _contratosPorFornecedor_ existem 56.855 CNPJs diferentes. Por algum motivo 5 CNPJs não foram localizados na base de dados. Como os não encontrados são poucos comparados ao tamanho do DataFrame, vamos desconsiderá-los no momento de juntar os dataframes.

# %% [markdown]
# Incluindo os significados dos códigos nas colunas que faltam:

# %%
dadosCadastroCnpj['identificador_matriz_filial'] = pd.Series(np.where(dadosCadastroCnpj['identificador_matriz_filial'].values == '1', 'MATRIZ', 'FILIAL'), dadosCadastroCnpj.index)

# %%
sit = { '01': 'Nula',
        '02': 'Ativa',
        '03': 'Suspensa',
        '04': 'Inapta',
        '08': 'Baixada' }

def situacaoCadastral(linha):
    return sit.get(linha['situacao_cadastral'], 'Não encontrada')

dadosCadastroCnpj['situacao_cadastral'] = dadosCadastroCnpj.apply(lambda linha: situacaoCadastral(linha), axis = 1)

# %%
porte = { '00': 'Não informado',
          '01': 'Micro Empresa',
          '03': 'Empresa de Pequeno Porte',
          '05': 'Demais' }

def porteEmpresa(linha):
    return porte.get(linha['porte_empresa'], 'Não encontrado')

dadosCadastroCnpj['porte_empresa'] = dadosCadastroCnpj.apply(lambda linha: porteEmpresa(linha), axis = 1)

# %%
simples = { '0': 'Não optante',
            '5': 'Optante',
            '7': 'Optante',
            '6': 'Excluída',
            '8': 'Excluída'}

def opcaoSimples(linha):
    return simples.get(linha['opcao_pelo_simples'], 'Não optante')

dadosCadastroCnpj['opcao_pelo_simples'] = dadosCadastroCnpj.apply(lambda linha: opcaoSimples(linha), axis = 1)

# %%
dadosCadastroCnpj.head()
# Out:
#              cnpj identificador_matriz_filial        razao_social  \
# 0  00000000000191                      MATRIZ  BANCO DO BRASIL SA
# 1  00000000096369                      FILIAL  BANCO DO BRASIL SA
# 2  00000000105104                      FILIAL  BANCO DO BRASIL SA
# 3  00000000304492                      FILIAL  BANCO DO BRASIL SA
# 4  00000000314455                      FILIAL  BANCO DO BRASIL SA
#
#   situacao_cadastral data_inicio_atividade  uf codigo_municipio  \
# 0              Ativa            1966-08-01  DF             9701
# 1              Ativa            1975-08-11  RN             1619
# 2              Ativa            1976-03-17  RJ             6001
# 3              Ativa            1991-04-12  SP             6477
# 4              Ativa            1991-04-02  DF             9701
#
#         municipio  capital_social_empresa porte_empresa opcao_pelo_simples  \
# 0        BRASILIA            9.000000e+10        Demais        Não optante
# 1           APODI            0.000000e+00        Demais        Não optante
# 2  RIO DE JANEIRO            0.000000e+00        Demais        Não optante
# 3       GUARULHOS            0.000000e+00        Demais        Não optante
# 4        BRASILIA            0.000000e+00        Demais        Não optante
#
#   cod_natureza_juridica    nm_natureza_juridica  \
# 0                     2  Entidades Empresariais
# 1                     2  Entidades Empresariais
# 2                     2  Entidades Empresariais
# 3                     2  Entidades Empresariais
# 4                     2  Entidades Empresariais
#
#   cod_subclass_natureza_juridica nm_subclass_natureza_juridica cod_secao  \
# 0                           2038   Sociedade de Economia Mista         K
# 1                           2038   Sociedade de Economia Mista         K
# 2                           2038   Sociedade de Economia Mista         K
# 3                           2038   Sociedade de Economia Mista         K
# 4                           2038   Sociedade de Economia Mista         K
#
#                                             nm_secao cod_divisao  \
# 0  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 1  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 2  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 3  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 4  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
#
#                            nm_divisao cod_grupo  \
# 0  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 1  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 2  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 3  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 4  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
#
#                                       nm_grupo cod_classe  \
# 0  Intermediação monetária - depósitos à vista    64.22-1
# 1  Intermediação monetária - depósitos à vista    64.21-2
# 2  Intermediação monetária - depósitos à vista    64.21-2
# 3  Intermediação monetária - depósitos à vista    64.22-1
# 4  Intermediação monetária - depósitos à vista    64.22-1
#
#                                  nm_classe cod_cnae  \
# 0  Bancos múltiplos com carteira comercial  6422100
# 1                        Bancos comerciais  6421200
# 2                        Bancos comerciais  6421200
# 3  Bancos múltiplos com carteira comercial  6422100
# 4  Bancos múltiplos com carteira comercial  6422100
#
#                                    nm_cnae
# 0  Bancos múltiplos com carteira comercial
# 1                        Bancos comerciais
# 2                        Bancos comerciais
# 3  Bancos múltiplos com carteira comercial
# 4  Bancos múltiplos com carteira comercial

# %%
dadosCadastroCnpj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56850 entries, 0 to 56849
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cnpj                            56850 non-null  object
#  1   identificador_matriz_filial     56850 non-null  object
#  2   razao_social                    56850 non-null  object
#  3   situacao_cadastral              56850 non-null  object
#  4   data_inicio_atividade           56850 non-null  object
#  5   uf                              56850 non-null  object
#  6   codigo_municipio                56850 non-null  object
#  7   municipio                       56850 non-null  object
#  8   capital_social_empresa          56850 non-null  float64
#  9   porte_empresa                   56850 non-null  object
#  10  opcao_pelo_simples              56850 non-null  object
#  11  cod_natureza_juridica           56850 non-null  object
#  12  nm_natureza_juridica            56850 non-null  object
#  13  cod_subclass_natureza_juridica  56850 non-null  object
#  14  nm_subclass_natureza_juridica   56850 non-null  object
#  15  cod_secao                       56850 non-null  object
#  16  nm_secao                        56850 non-null  object
#  17  cod_divisao                     56850 non-null  object
#  18  nm_divisao                      56850 non-null  object
#  19  cod_grupo                       56850 non-null  object
#  20  nm_grupo                        56850 non-null  object
#  21  cod_classe                      56850 non-null  object
#  22  nm_classe                       56850 non-null  object
#  23  cod_cnae                        56850 non-null  object
#  24  nm_cnae                         56850 non-null  object
# dtypes: float64(1), object(24)
# memory usage: 10.8+ MB

# %%
dadosCadastroCnpj.to_csv('./dadosCadastroCnpj.csv', index = False)

# %% [markdown]
# ## Criação do dataset
# Até o momento obtivemos os dados que consideramos necessários para tentar prever se um determinado fornecedor PJ tem tendência a descumprir contratos, porém os dados ainda estão separados em 4 dataframes (_dadosCadastroCnpj_, _licitacoesPorFornecedor_,  _contratosPorFornecedor_ e _ocorrenciasPorFornecedor_).

# %% [markdown]
# Além disso, precisamos definir a variável de interesse. Para isso, utilizaremos os dados das ocorrências. De modo simplificado, uma ocorrência é registrada no sistema cada vez que o fornecedor descumpre alguma regra da licitação ou cláusula contratual. Sendo assim, definiremos o risco de cada empresa com base na existência ou não de ocorrências registradas em seu CNPJ.

# %% [markdown]
# Primeiro, juntamos os dataframes _dadosCadastroCnpj_, _licitacoesPorFornecedor_ e _contratosPorFornecedor_, que serão as variáveis preditivas:

# %%
dadosCadastroCnpj = pd.read_csv('./dadosCadastroCnpj.csv', dtype = 'str')
licitacoesPorFornecedor = pd.read_csv('./licitacoesPorFornecedor.csv', dtype = 'str')
contratosPorFornecedor = pd.read_csv('./contratosPorFornecedor.csv', dtype = 'str')

# %%
dataset = pd.merge(dadosCadastroCnpj, licitacoesPorFornecedor, left_on = 'cnpj', right_on = 'CNPJ', how = 'left')
dataset = pd.merge(dataset, contratosPorFornecedor, left_on = 'cnpj', right_on = 'CNPJ', how = 'left')

# %% [markdown]
# A seguir, juntamos os dados das ocorrências:

# %%
dataset = pd.merge(dataset, ocorrenciasPorFornecedor, left_on = 'cnpj', right_on = 'CNPJ', how = 'left')

# %%
dataset.head()
# Out:
#              cnpj identificador_matriz_filial        razao_social  \
# 0  00000000000191                      MATRIZ  BANCO DO BRASIL SA
# 1  00000000096369                      FILIAL  BANCO DO BRASIL SA
# 2  00000000105104                      FILIAL  BANCO DO BRASIL SA
# 3  00000000304492                      FILIAL  BANCO DO BRASIL SA
# 4  00000000314455                      FILIAL  BANCO DO BRASIL SA
#
#   situacao_cadastral data_inicio_atividade  uf codigo_municipio  \
# 0              Ativa            1966-08-01  DF             9701
# 1              Ativa            1975-08-11  RN             1619
# 2              Ativa            1976-03-17  RJ             6001
# 3              Ativa            1991-04-12  SP             6477
# 4              Ativa            1991-04-02  DF             9701
#
#         municipio capital_social_empresa porte_empresa opcao_pelo_simples  \
# 0        BRASILIA          90000000000.0        Demais        Não optante
# 1           APODI                    0.0        Demais        Não optante
# 2  RIO DE JANEIRO                    0.0        Demais        Não optante
# 3       GUARULHOS                    0.0        Demais        Não optante
# 4        BRASILIA                    0.0        Demais        Não optante
#
#   cod_natureza_juridica    nm_natureza_juridica  \
# 0                     2  Entidades Empresariais
# 1                     2  Entidades Empresariais
# 2                     2  Entidades Empresariais
# 3                     2  Entidades Empresariais
# 4                     2  Entidades Empresariais
#
#   cod_subclass_natureza_juridica nm_subclass_natureza_juridica cod_secao  \
# 0                           2038   Sociedade de Economia Mista         K
# 1                           2038   Sociedade de Economia Mista         K
# 2                           2038   Sociedade de Economia Mista         K
# 3                           2038   Sociedade de Economia Mista         K
# 4                           2038   Sociedade de Economia Mista         K
#
#                                             nm_secao cod_divisao  \
# 0  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 1  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 2  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 3  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 4  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
#
#                            nm_divisao cod_grupo  \
# 0  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 1  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 2  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 3  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 4  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
#
#                                       nm_grupo cod_classe  \
# 0  Intermediação monetária - depósitos à vista    64.22-1
# 1  Intermediação monetária - depósitos à vista    64.21-2
# 2  Intermediação monetária - depósitos à vista    64.21-2
# 3  Intermediação monetária - depósitos à vista    64.22-1
# 4  Intermediação monetária - depósitos à vista    64.22-1
#
#                                  nm_classe cod_cnae  \
# 0  Bancos múltiplos com carteira comercial  6422100
# 1                        Bancos comerciais  6421200
# 2                        Bancos comerciais  6421200
# 3  Bancos múltiplos com carteira comercial  6422100
# 4  Bancos múltiplos com carteira comercial  6422100
#
#                                    nm_cnae          CNPJ_x participacoes  \
# 0  Bancos múltiplos com carteira comercial  00000000000191          6585
# 1                        Bancos comerciais  00000000096369             1
# 2                        Bancos comerciais             NaN           NaN
# 3  Bancos múltiplos com carteira comercial             NaN           NaN
# 4  Bancos múltiplos com carteira comercial             NaN           NaN
#
#   vitorias          CNPJ_y contratos            CNPJ  ocorrencias
# 0     6580  00000000000191        67  00000000000191          8.0
# 1        1  00000000096369         1             NaN          NaN
# 2      NaN  00000000105104         1             NaN          NaN
# 3      NaN  00000000304492         1             NaN          NaN
# 4      NaN  00000000314455         1             NaN          NaN

# %% [markdown]
# Vamos excluir as colunas _CNPJ_x_, _CNPJ_y_ e _CNPJ_, que trazem a mesma informação que a coluna _cnpj_:

# %%
dataset.drop(['CNPJ_x', 'CNPJ_y', 'CNPJ'], axis = 1, inplace = True)

# %% [markdown]
# Verificando valores nulos:

# %%
dataset.isnull().sum()
# Out:
# cnpj                                  0
# identificador_matriz_filial           0
# razao_social                          0
# situacao_cadastral                    0
# data_inicio_atividade                 0
# uf                                    0
# codigo_municipio                      0
# municipio                             0
# capital_social_empresa                0
# porte_empresa                         0
# opcao_pelo_simples                    0
# cod_natureza_juridica                 0
# nm_natureza_juridica                  0
# cod_subclass_natureza_juridica        0
# nm_subclass_natureza_juridica         0
# cod_secao                             0
# nm_secao                              0
# cod_divisao                           0
# nm_divisao                            0
# cod_grupo                             0
# nm_grupo                              0
# cod_classe                            0
# nm_classe                             0
# cod_cnae                              0
# nm_cnae                               0
# participacoes                      4104
# vitorias                           4104
# contratos                             0
# ocorrencias                       40652
# dtype: int64

# %% [markdown]
# As linhas que contém valores nulos na coluna _ocorrencias_ são as empresas que não tem nenhuma ocorrência registrada no sistema, portanto, são as empresas com baixo risco de descumprimento contratual. As que contém valores não nulos, por outro lado, são as empresas com maior risco. Então podemos substituir estes valores nulos por zero.

# %%
dataset['ocorrencias'].fillna(0, inplace = True)

# %% [markdown]
# Quanto aos valores nulos nas colunas _participacoes_ e _vitorias_, se tratam de empresas que possuem contratos com o governo federal mas não participaram de nenhuma licitação. Esta é uma situação que pode parecer estranha, porém verificando no Portal da Transparência, realmente existem contratações "Sem Processo Licitatório Associado". Sendo assim, substituiremos os valores nulos nestas colunas por 0.

# %%
dataset['participacoes'].fillna(0, inplace = True)
dataset['vitorias'].fillna(0, inplace = True)

# %%
dataset.isnull().sum()
# Out:
# cnpj                              0
# identificador_matriz_filial       0
# razao_social                      0
# situacao_cadastral                0
# data_inicio_atividade             0
# uf                                0
# codigo_municipio                  0
# municipio                         0
# capital_social_empresa            0
# porte_empresa                     0
# opcao_pelo_simples                0
# cod_natureza_juridica             0
# nm_natureza_juridica              0
# cod_subclass_natureza_juridica    0
# nm_subclass_natureza_juridica     0
# cod_secao                         0
# nm_secao                          0
# cod_divisao                       0
# nm_divisao                        0
# cod_grupo                         0
# nm_grupo                          0
# cod_classe                        0
# nm_classe                         0
# cod_cnae                          0
# nm_cnae                           0
# participacoes                     0
# vitorias                          0
# contratos                         0
# ocorrencias                       0
# dtype: int64

# %% [markdown]
# Agora, vamos criar a coluna do risco a partir da coluna _ocorrencias_, e depois excluir _ocorrencias_.

# %%
dataset['risco'] = dataset['ocorrencias'].apply(lambda x: 0 if x == 0 else 1)

# %%
dataset.drop(['ocorrencias'], axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#              cnpj identificador_matriz_filial        razao_social  \
# 0  00000000000191                      MATRIZ  BANCO DO BRASIL SA
# 1  00000000096369                      FILIAL  BANCO DO BRASIL SA
# 2  00000000105104                      FILIAL  BANCO DO BRASIL SA
# 3  00000000304492                      FILIAL  BANCO DO BRASIL SA
# 4  00000000314455                      FILIAL  BANCO DO BRASIL SA
#
#   situacao_cadastral data_inicio_atividade  uf codigo_municipio  \
# 0              Ativa            1966-08-01  DF             9701
# 1              Ativa            1975-08-11  RN             1619
# 2              Ativa            1976-03-17  RJ             6001
# 3              Ativa            1991-04-12  SP             6477
# 4              Ativa            1991-04-02  DF             9701
#
#         municipio capital_social_empresa porte_empresa opcao_pelo_simples  \
# 0        BRASILIA          90000000000.0        Demais        Não optante
# 1           APODI                    0.0        Demais        Não optante
# 2  RIO DE JANEIRO                    0.0        Demais        Não optante
# 3       GUARULHOS                    0.0        Demais        Não optante
# 4        BRASILIA                    0.0        Demais        Não optante
#
#   cod_natureza_juridica    nm_natureza_juridica  \
# 0                     2  Entidades Empresariais
# 1                     2  Entidades Empresariais
# 2                     2  Entidades Empresariais
# 3                     2  Entidades Empresariais
# 4                     2  Entidades Empresariais
#
#   cod_subclass_natureza_juridica nm_subclass_natureza_juridica cod_secao  \
# 0                           2038   Sociedade de Economia Mista         K
# 1                           2038   Sociedade de Economia Mista         K
# 2                           2038   Sociedade de Economia Mista         K
# 3                           2038   Sociedade de Economia Mista         K
# 4                           2038   Sociedade de Economia Mista         K
#
#                                             nm_secao cod_divisao  \
# 0  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 1  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 2  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 3  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 4  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
#
#                            nm_divisao cod_grupo  \
# 0  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 1  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 2  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 3  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 4  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
#
#                                       nm_grupo cod_classe  \
# 0  Intermediação monetária - depósitos à vista    64.22-1
# 1  Intermediação monetária - depósitos à vista    64.21-2
# 2  Intermediação monetária - depósitos à vista    64.21-2
# 3  Intermediação monetária - depósitos à vista    64.22-1
# 4  Intermediação monetária - depósitos à vista    64.22-1
#
#                                  nm_classe cod_cnae  \
# 0  Bancos múltiplos com carteira comercial  6422100
# 1                        Bancos comerciais  6421200
# 2                        Bancos comerciais  6421200
# 3  Bancos múltiplos com carteira comercial  6422100
# 4  Bancos múltiplos com carteira comercial  6422100
#
#                                    nm_cnae participacoes vitorias contratos  \
# 0  Bancos múltiplos com carteira comercial          6585     6580        67
# 1                        Bancos comerciais             1        1         1
# 2                        Bancos comerciais             0        0         1
# 3  Bancos múltiplos com carteira comercial             0        0         1
# 4  Bancos múltiplos com carteira comercial             0        0         1
#
#    risco
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
dataset.shape
# Out:
# (56850, 29)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56850 entries, 0 to 56849
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cnpj                            56850 non-null  object
#  1   identificador_matriz_filial     56850 non-null  object
#  2   razao_social                    56850 non-null  object
#  3   situacao_cadastral              56850 non-null  object
#  4   data_inicio_atividade           56850 non-null  object
#  5   uf                              56850 non-null  object
#  6   codigo_municipio                56850 non-null  object
#  7   municipio                       56850 non-null  object
#  8   capital_social_empresa          56850 non-null  object
#  9   porte_empresa                   56850 non-null  object
#  10  opcao_pelo_simples              56850 non-null  object
#  11  cod_natureza_juridica           56850 non-null  object
#  12  nm_natureza_juridica            56850 non-null  object
#  13  cod_subclass_natureza_juridica  56850 non-null  object
#  14  nm_subclass_natureza_juridica   56850 non-null  object
#  15  cod_secao                       56850 non-null  object
#  16  nm_secao                        56850 non-null  object
#  17  cod_divisao                     56850 non-null  object
#  18  nm_divisao                      56850 non-null  object
#  19  cod_grupo                       56850 non-null  object
#  20  nm_grupo                        56850 non-null  object
#  21  cod_classe                      56850 non-null  object
#  22  nm_classe                       56850 non-null  object
#  23  cod_cnae                        56850 non-null  object
#  24  nm_cnae                         56850 non-null  object
#  25  participacoes                   56850 non-null  object
#  26  vitorias                        56850 non-null  object
#  27  contratos                       56850 non-null  object
#  28  risco                           56850 non-null  int64
# dtypes: int64(1), object(28)
# memory usage: 13.0+ MB

# %% [markdown]
# Criamos então um dataset com 56.850 fornecedores do Governo Federal, com 29 colunas, sendo a coluna _risco_ a que queremos prever com o modelo de ML.

# %%
dataset.to_csv('./dataset.csv', index = False)
