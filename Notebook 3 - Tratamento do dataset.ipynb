# %% [markdown]
# # Tratamento dos dados

# %%
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.7.9

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sea
from IPython.display import display

pd.options.display.max_columns = None

# %% [markdown]
# Iniciaremos lendo o arquivo com o dataset:

# %%
dtypes = {  'cnpj': 'str',
            'razao_social': 'str',
            'identificador_matriz_filial': 'str',             
            'situacao_cadastral': 'str', 
            'data_inicio_atividade': 'str', 
            'uf': 'str', 
            'codigo_municipio': 'str', 
            'municipio': 'str', 
            'capital_social_empresa': 'float64',
            'porte_empresa': 'str', 
            'opcao_pelo_simples': 'str', 
            'cod_natureza_juridica': 'str', 
            'nm_natureza_juridica': 'str', 
            'cod_subclass_natureza_juridica': 'str', 
            'nm_subclass_natureza_juridica': 'str', 
            'cod_secao': 'str', 
            'nm_secao': 'str', 
            'cod_divisao': 'str', 
            'nm_divisao': 'str', 
            'cod_grupo': 'str', 
            'nm_grupo': 'str', 
            'cod_classe': 'str', 
            'nm_classe': 'str', 
            'cod_cnae': 'str', 
            'nm_cnae': 'str',
            'participacoes': 'int64',  
            'vitorias': 'int64',
            'contratos': 'int64',
            'risco': 'boolean' # Usamos boolean aqui, então onde havia o número 1 será True, representando empresa 
                               # com alto risco. Onde houver False temos empresa com baixo risco.
         }

# %%
dataset = pd.read_csv('./dataset.csv', dtype = dtypes)

# %%
dataset.head()
# Out:
#              cnpj identificador_matriz_filial        razao_social  \
# 0  00000000000191                      MATRIZ  BANCO DO BRASIL SA
# 1  00000000096369                      FILIAL  BANCO DO BRASIL SA
# 2  00000000105104                      FILIAL  BANCO DO BRASIL SA
# 3  00000000304492                      FILIAL  BANCO DO BRASIL SA
# 4  00000000314455                      FILIAL  BANCO DO BRASIL SA
#
#   situacao_cadastral data_inicio_atividade  uf codigo_municipio  \
# 0              Ativa            1966-08-01  DF             9701
# 1              Ativa            1975-08-11  RN             1619
# 2              Ativa            1976-03-17  RJ             6001
# 3              Ativa            1991-04-12  SP             6477
# 4              Ativa            1991-04-02  DF             9701
#
#         municipio  capital_social_empresa porte_empresa opcao_pelo_simples  \
# 0        BRASILIA            9.000000e+10        Demais        Não optante
# 1           APODI            0.000000e+00        Demais        Não optante
# 2  RIO DE JANEIRO            0.000000e+00        Demais        Não optante
# 3       GUARULHOS            0.000000e+00        Demais        Não optante
# 4        BRASILIA            0.000000e+00        Demais        Não optante
#
#   cod_natureza_juridica    nm_natureza_juridica  \
# 0                     2  Entidades Empresariais
# 1                     2  Entidades Empresariais
# 2                     2  Entidades Empresariais
# 3                     2  Entidades Empresariais
# 4                     2  Entidades Empresariais
#
#   cod_subclass_natureza_juridica nm_subclass_natureza_juridica cod_secao  \
# 0                           2038   Sociedade de Economia Mista         K
# 1                           2038   Sociedade de Economia Mista         K
# 2                           2038   Sociedade de Economia Mista         K
# 3                           2038   Sociedade de Economia Mista         K
# 4                           2038   Sociedade de Economia Mista         K
#
#                                             nm_secao cod_divisao  \
# 0  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 1  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 2  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 3  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
# 4  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...          64
#
#                            nm_divisao cod_grupo  \
# 0  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 1  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 2  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 3  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
# 4  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.2
#
#                                       nm_grupo cod_classe  \
# 0  Intermediação monetária - depósitos à vista    64.22-1
# 1  Intermediação monetária - depósitos à vista    64.21-2
# 2  Intermediação monetária - depósitos à vista    64.21-2
# 3  Intermediação monetária - depósitos à vista    64.22-1
# 4  Intermediação monetária - depósitos à vista    64.22-1
#
#                                  nm_classe cod_cnae  \
# 0  Bancos múltiplos com carteira comercial  6422100
# 1                        Bancos comerciais  6421200
# 2                        Bancos comerciais  6421200
# 3  Bancos múltiplos com carteira comercial  6422100
# 4  Bancos múltiplos com carteira comercial  6422100
#
#                                    nm_cnae  participacoes  vitorias  \
# 0  Bancos múltiplos com carteira comercial           6585      6580
# 1                        Bancos comerciais              1         1
# 2                        Bancos comerciais              0         0
# 3  Bancos múltiplos com carteira comercial              0         0
# 4  Bancos múltiplos com carteira comercial              0         0
#
#    contratos  risco
# 0         67   True
# 1          1  False
# 2          1  False
# 3          1  False
# 4          1  False

# %% [markdown]
# Não existem entradas nulas em nenhuma coluna:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56850 entries, 0 to 56849
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cnpj                            56850 non-null  object
#  1   identificador_matriz_filial     56850 non-null  object
#  2   razao_social                    56850 non-null  object
#  3   situacao_cadastral              56850 non-null  object
#  4   data_inicio_atividade           56850 non-null  object
#  5   uf                              56850 non-null  object
#  6   codigo_municipio                56850 non-null  object
#  7   municipio                       56850 non-null  object
#  8   capital_social_empresa          56850 non-null  float64
#  9   porte_empresa                   56850 non-null  object
#  10  opcao_pelo_simples              56850 non-null  object
#  11  cod_natureza_juridica           56850 non-null  object
#  12  nm_natureza_juridica            56850 non-null  object
#  13  cod_subclass_natureza_juridica  56850 non-null  object
#  14  nm_subclass_natureza_juridica   56850 non-null  object
#  15  cod_secao                       56850 non-null  object
#  16  nm_secao                        56850 non-null  object
#  17  cod_divisao                     56850 non-null  object
#  18  nm_divisao                      56850 non-null  object
#  19  cod_grupo                       56850 non-null  object
#  20  nm_grupo                        56850 non-null  object
#  21  cod_classe                      56850 non-null  object
#  22  nm_classe                       56850 non-null  object
#  23  cod_cnae                        56850 non-null  object
#  24  nm_cnae                         56850 non-null  object
#  25  participacoes                   56850 non-null  int64
#  26  vitorias                        56850 non-null  int64
#  27  contratos                       56850 non-null  int64
#  28  risco                           56850 non-null  boolean
# dtypes: boolean(1), float64(1), int64(3), object(24)
# memory usage: 12.3+ MB

# %% [markdown]
# Vamos iniciar o tratamento de algumas colunas, a fim de futuramente podermos aplicar algoritmos de ML.

# %% [markdown]
# * __identificador_matriz_filial__: vamos criar a coluna _identificador_matriz_, colocando o valor _True_ para Matriz e _False_ para Filial e excluir a coluna original

# %%
dataset['identificador_matriz'] = pd.Series(np.where(dataset['identificador_matriz_filial'].values == 'MATRIZ', True, False), dataset.index)
dataset.drop(['identificador_matriz_filial'], axis = 1, inplace = True)

# %% [markdown]
# * __codigo_municipio__ e __municipio__: verificando quantos valores únicos temos para cada uma das colunas relacionadas ao município:

# %%
print(dataset['codigo_municipio'].nunique())
print(dataset['municipio'].nunique())
# Out:
# 2256
# 2202

# %% [markdown]
# Notamos que existem mais códigos que nomes de municípios. Isto ocorre porque podem haver municípios com nomes iguais em estados diferentes. Além disso, vemos que existem 2.256 códigos de município diferentes. Vamos analisar a distribuição de empresas por código de munícipio:

# %%
quantidades = dataset['codigo_municipio'].value_counts().to_frame('quantidade_empresas').reset_index()
quant = pd.merge(quantidades.astype(str), dataset[['municipio', 'codigo_municipio']], left_on = 'index', right_on = 'codigo_municipio')
quant.drop_duplicates(inplace = True)
quant.drop(['index'], axis = 1, inplace = True)
quant = quant[['municipio', 'codigo_municipio', 'quantidade_empresas']]
quant['porcentagem_do_total'] = quant['quantidade_empresas'].astype(int).div(len(dataset.index)).mul(100)

# %%
quant.head(20)
# Out:
#             municipio codigo_municipio quantidade_empresas  \
# 0           SAO PAULO             7107                4395
# 4395         BRASILIA             9701                3760
# 8155   RIO DE JANEIRO             6001                3650
# 11805  BELO HORIZONTE             4123                2030
# 13835        CURITIBA             7535                1594
# 15429    PORTO ALEGRE             8801                1578
# 17007       FORTALEZA             1389                1162
# 18169          MANAUS             0255                1160
# 19329          RECIFE             2531                1068
# 20397         GOIANIA             9373                1025
# 21422        SALVADOR             3849                 982
# 22404           BELEM             0427                 975
# 23379    CAMPO GRANDE             9051                 765
# 24144           NATAL             1761                 695
# 24839        SAO LUIS             0921                 643
# 25482     PORTO VELHO             0003                 632
# 26114          CUIABA             9067                 604
# 26718        TERESINA             1219                 537
# 27255         ARACAJU             3105                 449
# 27704       BOA VISTA             0301                 445
#
#        porcentagem_do_total
# 0                  7.730871
# 4395               6.613896
# 8155               6.420405
# 11805              3.570800
# 13835              2.803870
# 15429              2.775726
# 17007              2.043975
# 18169              2.040457
# 19329              1.878628
# 20397              1.802990
# 21422              1.727353
# 22404              1.715040
# 23379              1.345646
# 24144              1.222515
# 24839              1.131047
# 25482              1.111697
# 26114              1.062445
# 26718              0.944591
# 27255              0.789798
# 27704              0.782762

# %% [markdown]
# Vamos agrupar os municípios que possuem menos de 1% do total das empresas e excluir a coluna com os códigos dos municípios, deixando a coluna com os nomes (optamos por deixar os nomes e não os códigos porque, nos munícipios que tem pelo menos 1% das empresas, não há nomes repetidos).

# %%
listaCidadesQueFicam = quant[quant['porcentagem_do_total'] > 1.0]['municipio'].to_list()
listaCidadesQueFicam
# Out:
# ['SAO PAULO',
#  'BRASILIA',
#  'RIO DE JANEIRO',
#  'BELO HORIZONTE',
#  'CURITIBA',
#  'PORTO ALEGRE',
#  'FORTALEZA',
#  'MANAUS',
#  'RECIFE',
#  'GOIANIA',
#  'SALVADOR',
#  'BELEM',
#  'CAMPO GRANDE',
#  'NATAL',
#  'SAO LUIS',
#  'PORTO VELHO',
#  'CUIABA']

# %%
dataset['municipio'] = pd.Series(np.where(np.isin(dataset['municipio'], listaCidadesQueFicam), dataset['municipio'], 'OUTROS'))
dataset.drop(['codigo_municipio'], axis = 1, inplace = True)
dataset['municipio'].value_counts()
# Out:
# OUTROS            30131
# SAO PAULO          4395
# BRASILIA           3760
# RIO DE JANEIRO     3650
# BELO HORIZONTE     2030
# CURITIBA           1594
# PORTO ALEGRE       1578
# FORTALEZA          1162
# MANAUS             1160
# RECIFE             1068
# GOIANIA            1025
# SALVADOR            982
# BELEM               975
# CAMPO GRANDE        766
# NATAL               695
# SAO LUIS            643
# PORTO VELHO         632
# CUIABA              604
# Name: municipio, dtype: int64

# %% [markdown]
# * __porte_empresa__: verificando as categorias exixtentes nesta coluna

# %%
dataset['porte_empresa'].value_counts()
# Out:
# Micro Empresa               21384
# Demais                      18540
# Empresa de Pequeno Porte    16924
# Não informado                   2
# Name: porte_empresa, dtype: int64

# %%
dataset[dataset['porte_empresa'] == 'Não informado']   #Verificando quais são as 2 empresas com porte não informado
# Out:
#                  cnpj                             razao_social  \
# 35761  15874855000119  MTU MAINTENANCE BERLIN-BRANDENBURG GMBH
# 43600  23685228000168          DEEP SEA SUPPLY SHIPOWNING I AS
#
#       situacao_cadastral data_inicio_atividade  uf municipio  \
# 35761              Ativa            2012-07-04  EX    OUTROS
# 43600              Ativa            2015-11-17  EX    OUTROS
#
#        capital_social_empresa  porte_empresa opcao_pelo_simples  \
# 35761                     0.0  Não informado        Não optante
# 43600                     0.0  Não informado        Não optante
#
#       cod_natureza_juridica    nm_natureza_juridica  \
# 35761                     2  Entidades Empresariais
# 43600                     2  Entidades Empresariais
#
#       cod_subclass_natureza_juridica    nm_subclass_natureza_juridica  \
# 35761                           2216  Empresa Domiciliada no Exterior
# 43600                           2216  Empresa Domiciliada no Exterior
#
#       cod_secao                                           nm_secao  \
# 35761         K  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...
# 43600         K  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...
#
#       cod_divisao                          nm_divisao cod_grupo  \
# 35761          64  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.6
# 43600          64  ATIVIDADES DE SERVIÇOS FINANCEIROS      64.6
#
#                                        nm_grupo cod_classe  \
# 35761  Atividades de sociedades de participação    64.62-0
# 43600  Atividades de sociedades de participação    64.62-0
#
#                                       nm_classe cod_cnae  \
# 35761  Holdings de instituições não financeiras  6462000
# 43600  Holdings de instituições não financeiras  6462000
#
#                                         nm_cnae  participacoes  vitorias  \
# 35761  Holdings de instituições não financeiras              0         0
# 43600  Holdings de instituições não financeiras              0         0
#
#        contratos  risco  identificador_matriz
# 35761          2  False                  True
# 43600          1  False                  True

# %% [markdown]
# As duas empresas com porte 'Não Informado' tem o CNAE _Holdings de instituições não financeiras_. Sendo assim, concluímos que não se tratam de Micro Empresas nem Empresas de Pequeno Porte, então vamos agrupá-las com as empresas com porte 'Demais'.

# %%
dataset['porte_empresa'] = pd.Series(np.where(dataset['porte_empresa'].values == 'Não informado', "Demais", dataset['porte_empresa']), dataset.index)
dataset['porte_empresa'].value_counts()
# Out:
# Micro Empresa               21384
# Demais                      18542
# Empresa de Pequeno Porte    16924
# Name: porte_empresa, dtype: int64

# %% [markdown]
# * __cod_natureza_juridica__, __nm_natureza_juridica__, __cod_subclass_natureza_juridica__ e __nm_subclass_natureza_juridica__: estas colunas estão relacionadas umas com as outras. As duas primeiras tem uma relação de um para um entre código e nome da natureza jurídica. As duas últimas são o código e nome da subclasse da natureza jurídica. Cada entrada de subclasse pertence à mesma natureza jurídica, enquanto cada natureza jurídica contém várias subclasses.

# %%
dataset['nm_natureza_juridica'].value_counts()
# Out:
# Entidades Empresariais           53882
# Entidades sem Fins Lucrativos     2476
# Administração Pública              488
# Pessoas Físicas                      4
# Name: nm_natureza_juridica, dtype: int64

# %%
dataset['nm_subclass_natureza_juridica'].nunique()
# Out:
# 50

# %% [markdown]
# Abaixo, verificamos a distribuição das empresas nas 50 subclasses de natureza jurídicas que existem no dataset.

# %%
quantidades = dataset['nm_subclass_natureza_juridica'].value_counts().to_frame('quantidade_empresas').reset_index().astype(str) 
quant = pd.merge(quantidades, dataset['nm_subclass_natureza_juridica'], left_on = 'index', right_on = 'nm_subclass_natureza_juridica')
quant.drop_duplicates(inplace = True)
quant.drop(['index'], axis = 1, inplace = True)
quant['porcentagem_do_total'] = quant['quantidade_empresas'].astype(int).div(len(dataset.index)).mul(100)
quant
# Out:
#       quantidade_empresas                      nm_subclass_natureza_juridica  \
# 0                   33335                      Sociedade Empresária Limitada
# 33335               10519  Empresa Individual de Responsabilidade Limitad...
# 43854                5124                            Empresário (Individual)
# 48978                1884                                 Associação Privada
# 50862                1723                         Sociedade Simples Limitada
# 52585                1507                          Sociedade Anônima Fechada
# 54092                 543                                        Cooperativa
# 54635                 520                             Sociedade Simples Pura
# 55155                 283                                   Fundação Privada
# 55438                 219                            Serviço Social Autônomo
# 55657                 213                                Autarquia Municipal
# 55870                 159                           Sociedade Anônima Aberta
# 56029                 134  Empresa Individual de Responsabilidade Limitad...
# 56163                 131                                    Empresa Pública
# 56294                 102                        Sociedade de Economia Mista
# 56396                  60                                          Município
# 56456                  58                            Consórcio de Sociedades
# 56514                  48         Órgão Público do Poder Executivo Municipal
# 56562                  40                                  Entidade Sindical
# 56602                  37           Órgão Público do Poder Executivo Federal
# 56639                  34          Autarquia Estadual ou do Distrito Federal
# 56673                  34                                  Autarquia Federal
# 56707                  25                              Organização Religiosa
# 56732                  25  Fundação Pública de Direito Público Estadual o...
# 56757                  17                                Condomínio Edilício
# 56774                  13  Órgão Público do Poder Executivo Estadual ou d...
# 56787                  10                    Empresa Domiciliada no Exterior
# 56797                   8        Fundação Pública de Direito Público Federal
# 56805                   7                        Clube/Fundo de Investimento
# 56812                   5            Serviço Notarial e Registral (Cartório)
# 56817                   5                  Sociedade Unipessoal de Advogados
# 56822                   4  Estabelecimento, no Brasil, de Sociedade Estra...
# 56826                   2  Fundação Pública de Direito Privado Estadual o...
# 56828                   2      Fundação Pública de Direito Público Municipal
# 56830                   2                   Órgão Público Autônomo Municipal
# 56832                   2                     Empresa Individual Imobiliária
# 56834                   2    Fundo Público da Administração Direta Municipal
# 56836                   2                     Produtor Rural (Pessoa Física)
# 56838                   1              Sociedade Empresária em Nome Coletivo
# 56839                   1  Consórcio Público de Direito Público (Associaç...
# 56840                   1                            Organização Social (OS)
# 56841                   1        Fundação Pública de Direito Privado Federal
# 56842                   1  Fundo Público da Administração Direta Estadual...
# 56843                   1         Órgão Público do Poder Judiciário Estadual
# 56844                   1                  Entidade de Mediação e Arbitragem
# 56845                   1  Estabelecimento, no Brasil, de Fundação ou Ass...
# 56846                   1      Fundação Pública de Direito Privado Municipal
# 56847                   1  Órgão Público do Poder Legislativo Estadual ou...
# 56848                   1  Órgão Público Autônomo Estadual ou do Distrito...
# 56849                   1                         Estado ou Distrito Federal
#
#        porcentagem_do_total
# 0                 58.636763
# 33335             18.503078
# 43854              9.013193
# 48978              3.313984
# 50862              3.030783
# 52585              2.650836
# 54092              0.955145
# 54635              0.914688
# 55155              0.497801
# 55438              0.385224
# 55657              0.374670
# 55870              0.279683
# 56029              0.235708
# 56163              0.230431
# 56294              0.179420
# 56396              0.105541
# 56456              0.102023
# 56514              0.084433
# 56562              0.070361
# 56602              0.065084
# 56639              0.059807
# 56673              0.059807
# 56707              0.043975
# 56732              0.043975
# 56757              0.029903
# 56774              0.022867
# 56787              0.017590
# 56797              0.014072
# 56805              0.012313
# 56812              0.008795
# 56817              0.008795
# 56822              0.007036
# 56826              0.003518
# 56828              0.003518
# 56830              0.003518
# 56832              0.003518
# 56834              0.003518
# 56836              0.003518
# 56838              0.001759
# 56839              0.001759
# 56840              0.001759
# 56841              0.001759
# 56842              0.001759
# 56843              0.001759
# 56844              0.001759
# 56845              0.001759
# 56846              0.001759
# 56847              0.001759
# 56848              0.001759
# 56849              0.001759

# %% [markdown]
# Vamos agrupar as subclasses que possuem menos de 1% do total das empresas e excluir as colunas _cod_natureza_juridica_, _nm_natureza_juridica_ e _cod_subclass_natureza_juridica_, mantendo a coluna _nm_subclass_natureza_juridica_.

# %%
listaSubclassesQueFicam = quant[quant['porcentagem_do_total'] > 1.0]['nm_subclass_natureza_juridica'].to_list()
listaSubclassesQueFicam
# Out:
# ['Sociedade Empresária Limitada',
#  'Empresa Individual de Responsabilidade Limitada (de Natureza Empresária)',
#  'Empresário (Individual)',
#  'Associação Privada',
#  'Sociedade Simples Limitada',
#  'Sociedade Anônima Fechada']

# %%
dataset['nm_subclass_natureza_juridica'] = pd.Series(np.where(np.isin(dataset['nm_subclass_natureza_juridica'], listaSubclassesQueFicam), dataset['nm_subclass_natureza_juridica'], 'Outros'))
dataset.drop(['cod_natureza_juridica', 'nm_natureza_juridica', 'cod_subclass_natureza_juridica'], axis = 1, inplace = True)

# %% [markdown]
# * __cod_secao__, __nm_secao__, __cod_divisao__, __nm_divisao__, __cod_grupo__, __nm_grupo__, __cod_classe__, __nm_classe__, __cod_cnae__, __nm_cnae__: estas dez colunas se referem ao CNAE, sendo _cod_secao_ e _nm_secao_ mais abrangentes e _cod_cnae_ e _nm_cnae_ mais detalhados. Vamos verificar as quantidades de categorias para cada nível da classificação:

# %%
print(dataset['nm_secao'].nunique())
print(dataset['nm_divisao'].nunique())
print(dataset['nm_grupo'].nunique())
print(dataset['nm_classe'].nunique())
print(dataset['nm_cnae'].nunique())
# Out:
# 20
# 82
# 263
# 594
# 1018

# %% [markdown]
# Distribuição das empresas por _Seção_:

# %%
qt = dataset['nm_secao'].value_counts(normalize = True).to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'Seção CNAE'}, inplace = True)
qt
# Out:
#                                            Seção CNAE  Porcentagem empresas
# 0   COMÉRCIO REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...              0.287388
# 1                     SAÚDE HUMANA E SERVIÇOS SOCIAIS              0.127916
# 2                                          CONSTRUÇÃO              0.118153
# 3   ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEME...              0.104573
# 4                         INDÚSTRIAS DE TRANSFORMAÇÃO              0.100176
# 5     ATIVIDADES PROFISSIONAIS CIENTÍFICAS E TÉCNICAS              0.065383
# 6                            INFORMAÇÃO E COMUNICAÇÃO              0.051856
# 7                       OUTRAS ATIVIDADES DE SERVIÇOS              0.035497
# 8                    TRANSPORTE ARMAZENAGEM E CORREIO              0.025101
# 9                                            EDUCAÇÃO              0.021759
# 10                           ALOJAMENTO E ALIMENTAÇÃO              0.014442
# 11  ÁGUA ESGOTO ATIVIDADES DE GESTÃO DE RESÍDUOS E...              0.012102
# 12                  ARTES CULTURA ESPORTE E RECREAÇÃO              0.010906
# 13                            ATIVIDADES IMOBILIÁRIAS              0.008478
# 14  ATIVIDADES FINANCEIRAS DE SEGUROS E SERVIÇOS R...              0.005822
# 15   ADMINISTRAÇÃO PÚBLICA DEFESA E SEGURIDADE SOCIAL              0.004450
# 16  AGRICULTURA PECUÁRIA PRODUÇÃO FLORESTAL PESCA ...              0.002990
# 17                                 ELETRICIDADE E GÁS              0.002111
# 18                              INDÚSTRIAS EXTRATIVAS              0.000862
# 19                                SERVIÇOS DOMÉSTICOS              0.000035

# %% [markdown]
# Distribuição das empresas por _Divisão_:

# %%
qt = dataset['nm_divisao'].value_counts(normalize = True).iloc[:20].to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'Divisão CNAE'}, inplace = True)
df = pd.DataFrame({'Divisão CNAE': ['OUTROS'], 'Porcentagem empresas': [1.0 - qt['Porcentagem empresas'].sum()]})
qt = qt.append(df)
qt
# Out:
#                                          Divisão CNAE  Porcentagem empresas
# 0                                  COMÉRCIO VAREJISTA              0.155884
# 1                ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA              0.118804
# 2   COMÉRCIO POR ATACADO EXCETO VEÍCULOS AUTOMOTOR...              0.105084
# 3                             CONSTRUÇÃO DE EDIFÍCIOS              0.060264
# 4             SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO              0.041777
# 5   SERVIÇOS DE ARQUITETURA E ENGENHARIA TESTES E ...              0.039789
# 6   SERVIÇOS PARA EDIFÍCIOS E ATIVIDADES PAISAGÍST...              0.031469
# 7   SERVIÇOS DE ESCRITÓRIO DE APOIO ADMINISTRATIVO...              0.027282
# 8   COMÉRCIO E REPARAÇÃO DE VEÍCULOS AUTOMOTORES E...              0.026420
# 9                                            EDUCAÇÃO              0.021759
# 10  ATIVIDADES DOS SERVIÇOS DE TECNOLOGIA DA INFOR...              0.020792
# 11            ATIVIDADES DE ORGANIZAÇÕES ASSOCIATIVAS              0.020704
# 12                               TRANSPORTE TERRESTRE              0.017256
# 13  MANUTENÇÃO REPARAÇÃO E INSTALAÇÃO DE MÁQUINAS ...              0.016816
# 14                            OBRAS DE INFRAESTRUTURA              0.016113
# 15  ALUGUÉIS NÃO IMOBILIÁRIOS E GESTÃO DE ATIVOS I...              0.015919
# 16  ATIVIDADES DE VIGILÂNCIA SEGURANÇA E INVESTIGAÇÃO              0.015726
# 17                                        ALIMENTAÇÃO              0.011715
# 18                                   TELECOMUNICAÇÕES              0.011469
# 19                IMPRESSÃO E REPRODUÇÃO DE GRAVAÇÕES              0.009622
# 0                                              OUTROS              0.215339

# %% [markdown]
# Distribuição das empresas por _Grupo_:

# %%
qt = dataset['nm_grupo'].value_counts(normalize = True).iloc[:20].to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'Grupo CNAE'}, inplace = True)
df = pd.DataFrame({'Grupo CNAE': ['OUTROS'], 'Porcentagem empresas': [1.0 - qt['Porcentagem empresas'].sum()]})
qt = qt.append(df)
qt
# Out:
#                                            Grupo CNAE  Porcentagem empresas
# 0                             Construção de edifícios              0.058206
# 1   Comércio varejista de equipamentos de informát...              0.053316
# 2   Atividades de atenção ambulatorial executadas ...              0.040686
# 3   Comércio atacadista de produtos de consumo não...              0.039226
# 4   Serviços de arquitetura e engenharia e ativida...              0.037397
# 5   Atividades de serviços de complementação diagn...              0.032788
# 6   Comércio varejista de produtos novos não espec...              0.029041
# 7   Instalações elétricas hidráulicas e outras ins...              0.026667
# 8        Comércio varejista de material de construção              0.025963
# 9                               Atividades de limpeza              0.025347
# 10  Atividades de profissionais da área de saúde e...              0.023641
# 11  Comércio atacadista de máquinas aparelhos e eq...              0.022885
# 12  Atividades dos serviços de tecnologia da infor...              0.020792
# 13               Atividades de atendimento hospitalar              0.018047
# 14  Manutenção e reparação de máquinas e equipamentos              0.014881
# 15                        Outras atividades de ensino              0.014811
# 16  Comércio de peças e acessórios para veículos a...              0.014705
# 17  Atividades de associações de defesa de direito...              0.012788
# 18  Atividades de vigilância segurança privada e t...              0.012366
# 19      Serviços de escritório e apoio administrativo              0.012243
# 0                                              OUTROS              0.464204

# %% [markdown]
# Distribuição das empresas por _Classe_:

# %%
qt = dataset['nm_classe'].value_counts(normalize = True).iloc[:20].to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'Classe CNAE'}, inplace = True)
df = pd.DataFrame({'Classe CNAE': ['OUTROS'], 'Porcentagem empresas': [1.0 - qt['Porcentagem empresas'].sum()]})
qt = qt.append(df)
qt
# Out:
#                                           Classe CNAE  Porcentagem empresas
# 0                             Construção de edifícios              0.058206
# 1   Atividades de atenção ambulatorial executadas ...              0.040686
# 2   Atividades de serviços de complementação diagn...              0.032788
# 3                              Serviços de engenharia              0.028531
# 4   Comércio varejista especializado de equipament...              0.026895
# 5   Atividades de profissionais da área de saúde e...              0.023641
# 6   Comércio varejista de outros produtos novos nã...              0.021882
# 7                Atividades de atendimento hospitalar              0.018047
# 8   Comércio atacadista de instrumentos e materiai...              0.017643
# 9   Comércio varejista de ferragens madeira e mate...              0.017397
# 10  Comércio de peças e acessórios para veículos a...              0.014705
# 11                 Limpeza em prédios e em domicílios              0.014301
# 12  Atividades de ensino não especificadas anterio...              0.013122
# 13  Atividades de associações de defesa de direito...              0.012788
# 14       Atividades de vigilância e segurança privada              0.011961
# 15  Instalações hidráulicas de sistemas de ventila...              0.011117
# 16                              Instalações elétricas              0.009938
# 17  Comércio varejista de livros jornais revistas ...              0.009903
# 18                     Transporte rodoviário de carga              0.008936
# 19  Atividades de organização de eventos exceto cu...              0.008637
# 0                                              OUTROS              0.598874

# %% [markdown]
# Distribuição das empresas por _CNAE_:

# %%
qt = dataset['nm_cnae'].value_counts(normalize = True).iloc[:15].to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'CNAE'}, inplace = True)
df = pd.DataFrame({'CNAE': ['OUTROS'], 'Porcentagem empresas': [1.0 - qt['Porcentagem empresas'].sum()]})
qt = qt.append(df)
qt
# Out:
#                                                  CNAE  Porcentagem empresas
# 0                             Construção de edifícios              0.058206
# 1                              Serviços de engenharia              0.028531
# 2   Comércio varejista especializado de equipament...              0.026491
# 3   Atividade médica ambulatorial restrita a consu...              0.018399
# 4   Comércio atacadista de instrumentos e materiai...              0.016447
# 5   Atividades de atendimento hospitalar exceto pr...              0.014565
# 6                  Limpeza em prédios e em domicílios              0.014301
# 7                          Atividades de fisioterapia              0.013931
# 8   Comércio varejista de outros produtos não espe...              0.013826
# 9   Atividades de associações de defesa de direito...              0.012788
# 10       Atividades de vigilância e segurança privada              0.011891
# 11  Comércio a varejo de peças e acessórios novos ...              0.010818
# 12                   Instalação e manutenção elétrica              0.009938
# 13                              Laboratórios clínicos              0.009164
# 14  Instalação e manutenção de sistemas centrais d...              0.009077
# 0                                              OUTROS              0.731627

# %% [markdown]
# Observamos que granularidade é tanta que já no nível de _Grupo_, só duas categorias representam mais de 5% dos dados. Sendo assim, optamos por manter apenas as informações de _Seção_ e _Divisão_. Vamos agrupar as seções e as divisões que possuem menos de 1% do total das empresas.

# %%
qt = dataset['nm_secao'].value_counts(normalize = True).to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'nm_secao'}, inplace = True)
listaSecoesQueFicam = qt[qt['Porcentagem empresas'] > 0.01]['nm_secao'].to_list()
dataset['nm_secao'] = pd.Series(np.where(np.isin(dataset['nm_secao'], listaSecoesQueFicam), dataset['nm_secao'], 'Outros'))

# %%
qt = dataset['nm_divisao'].value_counts(normalize = True).to_frame('Porcentagem empresas').reset_index()
qt.rename(columns = {'index': 'nm_divisao'}, inplace = True)
listaDivisoesQueFicam = qt[qt['Porcentagem empresas'] > 0.01]['nm_divisao'].to_list()
dataset['nm_divisao'] = pd.Series(np.where(np.isin(dataset['nm_divisao'], listaDivisoesQueFicam), dataset['nm_divisao'], 'Outros'))

# %%
dataset.drop(['cod_secao', 
              'cod_divisao', 
              'cod_grupo', 
              'nm_grupo', 
              'cod_classe', 
              'nm_classe', 
              'cod_cnae', 
              'nm_cnae'], axis = 1, inplace = True)

# %%
print('Seções')
print(dataset['nm_secao'].nunique())
print('Divisões')
print(dataset['nm_divisao'].nunique())
# Out:
# Seções
# 14
# Divisões
# 20

# %% [markdown]
# * __data_inicio_atividade__: acreditamos que mais importante que a data exata de início de atividade de uma empresa seja a quantidade de anos de existência. Então vamos criar uma nova coluna com a idade da empresa e excluir a data de início de atividade

# %%
dataset['idade_empresa'] = 2021 - dataset['data_inicio_atividade'].str.split('-', expand = True)[0].astype(int)
dataset.drop(['data_inicio_atividade'], axis = 1, inplace = True)

# %%
dataset['idade_empresa'].describe()
# Out:
# count    56850.000000
# mean        18.539402
# std         11.602314
# min          1.000000
# 25%         10.000000
# 50%         16.000000
# 75%         24.000000
# max        114.000000
# Name: idade_empresa, dtype: float64

# %% [markdown]
# * __situacao_cadastral__

# %%
dataset['situacao_cadastral'].value_counts(normalize = True)
# Out:
# Ativa       0.921337
# Baixada     0.043676
# Inapta      0.032454
# Suspensa    0.002498
# Nula        0.000035
# Name: situacao_cadastral, dtype: float64

# %% [markdown]
# As empresas na situação _Ativa_ representam mais de 90% dos dados, então vamos transformar a coluna _situacao_cadastral_ em um indicador de se a empresa está ativa ou não.

# %%
dataset['situacao_cadastral_ativa'] = pd.Series(np.where(dataset['situacao_cadastral'].values == 'Ativa', True, False), dataset.index)
dataset.drop(['situacao_cadastral'], axis = 1, inplace = True)

# %% [markdown]
# Após o tratamento das colunas feito acima, ficamos com seguinte dataset, contendo 56.850 fornecedores do Governo Federal, com 17 colunas, sendo a coluna _risco_ a que queremos prever com o modelo de ML.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56850 entries, 0 to 56849
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cnpj                           56850 non-null  object
#  1   razao_social                   56850 non-null  object
#  2   uf                             56850 non-null  object
#  3   municipio                      56850 non-null  object
#  4   capital_social_empresa         56850 non-null  float64
#  5   porte_empresa                  56850 non-null  object
#  6   opcao_pelo_simples             56850 non-null  object
#  7   nm_subclass_natureza_juridica  56850 non-null  object
#  8   nm_secao                       56850 non-null  object
#  9   nm_divisao                     56850 non-null  object
#  10  participacoes                  56850 non-null  int64
#  11  vitorias                       56850 non-null  int64
#  12  contratos                      56850 non-null  int64
#  13  risco                          56850 non-null  boolean
#  14  identificador_matriz           56850 non-null  bool
#  15  idade_empresa                  56850 non-null  int32
#  16  situacao_cadastral_ativa       56850 non-null  bool
# dtypes: bool(2), boolean(1), float64(1), int32(1), int64(3), object(9)
# memory usage: 6.1+ MB

# %%
dataset.describe()
# Out:
#        capital_social_empresa  participacoes      vitorias     contratos  \
# count            5.685000e+04   56850.000000  56850.000000  56850.000000
# mean             2.416621e+07     773.320211    127.203342      4.667142
# std              7.912435e+08    3987.962876    743.158312     18.977881
# min              0.000000e+00       0.000000      0.000000      1.000000
# 25%              1.000000e+04       2.000000      2.000000      1.000000
# 50%              1.000000e+05      21.000000      6.000000      2.000000
# 75%              4.500000e+05     227.000000     41.000000      4.000000
# max              9.000000e+10  239891.000000  50899.000000   1633.000000
#
#        idade_empresa
# count   56850.000000
# mean       18.539402
# std        11.602314
# min         1.000000
# 25%        10.000000
# 50%        16.000000
# 75%        24.000000
# max       114.000000

# %%
dataset
# Out:
#                  cnpj                                       razao_social  uf  \
# 0      00000000000191                                 BANCO DO BRASIL SA  DF
# 1      00000000096369                                 BANCO DO BRASIL SA  RN
# 2      00000000105104                                 BANCO DO BRASIL SA  RJ
# 3      00000000304492                                 BANCO DO BRASIL SA  SP
# 4      00000000314455                                 BANCO DO BRASIL SA  DF
# ...               ...                                                ...  ..
# 56845  98413339000114                                  JOSE BRAZ RISPOLI  RS
# 56846  98416225000128               SANTA CASA DE CARIDADE DE URUGUAIANA  RS
# 56847  98420052000111  LABORATORIO DE ANALISES CLINICAS TARRAGO CARVA...  RS
# 56848  98526122000110                         MITRA DIOCESANA DE VACARIA  RS
# 56849  98669997000171          E. R. AMANTINO INDUSTRIA METALURGICA LTDA  RS
#
#             municipio  capital_social_empresa             porte_empresa  \
# 0            BRASILIA            9.000000e+10                    Demais
# 1              OUTROS            0.000000e+00                    Demais
# 2      RIO DE JANEIRO            0.000000e+00                    Demais
# 3              OUTROS            0.000000e+00                    Demais
# 4            BRASILIA            0.000000e+00                    Demais
# ...               ...                     ...                       ...
# 56845          OUTROS            2.500000e+04  Empresa de Pequeno Porte
# 56846          OUTROS            0.000000e+00                    Demais
# 56847          OUTROS            4.000000e+04             Micro Empresa
# 56848          OUTROS            0.000000e+00                    Demais
# 56849          OUTROS            2.550000e+06                    Demais
#
#       opcao_pelo_simples  nm_subclass_natureza_juridica  \
# 0            Não optante                         Outros
# 1            Não optante                         Outros
# 2            Não optante                         Outros
# 3            Não optante                         Outros
# 4            Não optante                         Outros
# ...                  ...                            ...
# 56845            Optante        Empresário (Individual)
# 56846        Não optante             Associação Privada
# 56847            Optante  Sociedade Empresária Limitada
# 56848        Não optante                         Outros
# 56849        Não optante  Sociedade Empresária Limitada
#
#                                                 nm_secao  \
# 0                                                 Outros
# 1                                                 Outros
# 2                                                 Outros
# 3                                                 Outros
# 4                                                 Outros
# ...                                                  ...
# 56845  COMÉRCIO REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...
# 56846                    SAÚDE HUMANA E SERVIÇOS SOCIAIS
# 56847                    SAÚDE HUMANA E SERVIÇOS SOCIAIS
# 56848                      OUTRAS ATIVIDADES DE SERVIÇOS
# 56849                        INDÚSTRIAS DE TRANSFORMAÇÃO
#
#                                     nm_divisao  participacoes  vitorias  \
# 0                                       Outros           6585      6580
# 1                                       Outros              1         1
# 2                                       Outros              0         0
# 3                                       Outros              0         0
# 4                                       Outros              0         0
# ...                                        ...            ...       ...
# 56845                       COMÉRCIO VAREJISTA             82        40
# 56846     ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA              2         2
# 56847     ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA              2         2
# 56848  ATIVIDADES DE ORGANIZAÇÕES ASSOCIATIVAS              1         1
# 56849                                   Outros           1833      1788
#
#        contratos  risco  identificador_matriz  idade_empresa  \
# 0             67   True                  True             55
# 1              1  False                 False             46
# 2              1  False                 False             45
# 3              1  False                 False             30
# 4              1  False                 False             30
# ...          ...    ...                   ...            ...
# 56845          1  False                  True             54
# 56846          2  False                  True             53
# 56847          2  False                  True             50
# 56848          1  False                  True             50
# 56849          1  False                  True             55
#
#        situacao_cadastral_ativa
# 0                          True
# 1                          True
# 2                          True
# 3                          True
# 4                          True
# ...                         ...
# 56845                      True
# 56846                      True
# 56847                      True
# 56848                      True
# 56849                      True
#
# [56850 rows x 17 columns]

# %%
dataset.to_csv('./dataset_tratado.csv', index = False)
